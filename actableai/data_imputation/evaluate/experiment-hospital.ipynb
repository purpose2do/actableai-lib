# %%
import os
os.chdir('..')

# %%
# %load_ext autoreload
# %autoreload 2

from data import DataFrame
from actableai.data_imputation.meta import ColumnType
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
os.chdir('evaluate')
# Out:
# /home/hoang/anaconda3/envs/data_impute/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
BROKEN_CSV = "../experiments/data/hospital/hospital_drop.csv"

df = DataFrame(BROKEN_CSV)

print(df.column_types["Score"])

df.override_column_type("Score", ColumnType.Percentage)

print(df.column_types["Score"])

# df.column_types, errors
# Out:
# ColumnType.Category
# ColumnType.Percentage
# /home/hoang/Desktop/AI/data_impute/data/data_frame.py:46: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._fix_strategy = {col: FixStrategy.UNDECIDED for col in df.columns}

# %%
import pandas as pd
raw_df = pd.read_csv(BROKEN_CSV)
print(raw_df.dtypes)
# Out:
# ProviderNumber       object
# HospitalName         object
# Address1             object
# Address2            float64
# Address3            float64
# City                 object
# State                object
# ZipCode              object
# CountyName           object
# PhoneNumber          object
# HospitalType         object
# HospitalOwner        object
# EmergencyService     object
# Condition            object
# MeasureCode          object
# MeasureName          object
# Score                object
# Sample               object
# Stateavg             object
# dtype: object
# /home/hoang/anaconda3/envs/data_impute/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
raw_df.Score.unique()
# Out:
# array([nan, '97%', '92%', '75%', '100%', '86%', '80%', '99%', '98%',
#        '96%', '72%', '78%', '91%', '93%', '89%', '84%', '94%', '88%',
#        '90%', '83%', '60%', '81%', '36%', '95%', '74%', '79%', '82%',
#        '50%', '87%', '64%', '0%', 'x00%', '4%', '25%', '33%', '62%',
#        '47%', '9x%', '67%', 'x7%', '95x', '85%', 'x5%', '40%', 'xx%',
#        '89x', 'x6%', '71%', 'x4%', '1xx%', '77%', '66%', '68%', '93x',
#        '45%', '54%', '32%', '38%', '12%', '46%', '69%', '76%', 'x3%',
#        '14%', '80x', '53%', '63%', '65%', '43%'], dtype=object)

# %%
fixed_df = df.auto_fix()

fixed_df.to_csv("../experiments/data/hospital/repaired-from-my.csv", index=False)

fixed_df.fix_strategy
# Out:
# Detecting NULL errors for ProviderNumber
# Detecting NULL errors for HospitalName
# Detecting NULL errors for Address1
# Detecting NULL errors for Address2
# Detecting NULL errors for Address3
# Detecting NULL errors for City
# Detecting NULL errors for State
# Detecting NULL errors for ZipCode
# Detecting NULL errors for CountyName
# Detecting NULL errors for PhoneNumber
# Detecting NULL errors for HospitalType
# Detecting NULL errors for HospitalOwner
# Detecting NULL errors for EmergencyService
# Detecting NULL errors for Condition
# Detecting NULL errors for MeasureCode
# Detecting NULL errors for MeasureName
# Detecting NULL errors for Score
# Detecting NULL errors for Sample
# Detecting NULL errors for Stateavg
# Detecting MISPLACED errors for ProviderNumber
# Detecting MISPLACED errors for HospitalName
# Detecting MISPLACED errors for Address1
# Detecting MISPLACED errors for Address2
# Detecting MISPLACED errors for Address3
# Detecting MISPLACED errors for City
# ...

# %%
fixed_df.dtypes
# Out:
# /home/hoang/anaconda3/envs/data_impute/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ProviderNumber      object
# HospitalName        object
# Address1            object
# Address2            object
# Address3            object
# City                object
# State               object
# ZipCode             object
# CountyName          object
# PhoneNumber         object
# HospitalType        object
# HospitalOwner       object
# EmergencyService    object
# Condition           object
# MeasureCode         object
# MeasureName         object
# Score               object
# Sample              object
# Stateavg            object
# dtype: object

# %%
len(fixed_df.columns)
# Out:
# 19

# %%
len(raw_df.columns)
# Out:
# 19

# %%
fixed_df = df.auto_fix()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/data_impute/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Address2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.columns
# Out:
# /home/hoang/anaconda3/envs/data_impute/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Index(['ProviderNumber', 'HospitalName', 'Address1', 'Address2', 'Address3',
#        'City', 'State', 'ZipCode', 'CountyName', 'PhoneNumber', 'HospitalType',
#        'HospitalOwner', 'EmergencyService', 'Condition', 'MeasureCode',
#        'MeasureName', 'Score', 'Sample', 'Stateavg'],
#       dtype='object')

# %%
raw_df.head(1)
# Out:
# /home/hoang/anaconda3/envs/data_impute/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   ProviderNumber                      HospitalName              Address1  \
# 0          10018  callahan eye foundation hospital  1720 university blvd
#
#    Address2  Address3        City State ZipCode CountyName PhoneNumber  \
# 0       NaN       NaN  birmingham    al   35233  jefferson  2053258100
#
#            HospitalType                   HospitalOwner EmergencyService  \
# 0  acute care hospitals  voluntary non-profit - private              yes
#
#                        Condition  MeasureCode  \
# 0  surgical infection prevention  scip-card-2
#
# ...

# %%
fixed_df[pd.isnull(fixed_df['Sample'])]
# Out:
# /home/hoang/anaconda3/envs/data_impute/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     ProviderNumber                        HospitalName               Address1  \
# 0            10018    callahan eye foundation hospital   1720 university blvd
# 1            10018    callahan eye foundation hospital   1720 university blvd
# 2            10018    callahan eye foundation hospital   1720 university blvd
# 3            10018    callahan eye foundation hospital   1720 university blvd
# 4            10018    callahan eye foundation hospital   1720 university blvd
# 5            10018    callahan eye foundation hospital   1720 university blvd
# ...

# %%
from evaluate import evaluate

evaluate("hospital")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-b73f5ae7072a> in <module>
#       1 from evaluate import evaluate
#       2
# ----> 3 evaluate("hospital")
#
# ~/Desktop/AI/data_impute/evaluate/evaluate.py in evaluate(data_name, new_version)
#      12
#      13     clean_csv = pd.read_csv(CLEAN_CSV)
# ---> 14     hc_fixed_csv = pd.read_csv(HOLOCLEAN_FIXED_CSV)
#      15     my_fixed_csv = pd.read_csv(MY_FIXED_CSV)
#      16
#
# ...
