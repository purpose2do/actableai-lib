# %%
# %load_ext autoreload
# %autoreload 1
# %aimport actableai.timeseries.params
# %aimport actableai.timeseries.models

import pandas as pd
from datetime import timedelta
from matplotlib import pyplot as plt

import ray
import torch
import numpy as np
import json
import mxnet as mx
import json

# %%
ray.init()
# Out:
# 2021-01-29 15:26:34,570	INFO services.py:1171 -- View the Ray dashboard at http://127.0.0.1:8266
# {'node_ip_address': '172.16.2.58',
#  'raylet_ip_address': '172.16.2.58',
#  'redis_address': '172.16.2.58:27507',
#  'object_store_address': '/tmp/ray/session_2021-01-29_15-26-33_941870_200906/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2021-01-29_15-26-33_941870_200906/sockets/raylet',
#  'webui_url': '127.0.0.1:8266',
#  'session_dir': '/tmp/ray/session_2021-01-29_15-26-33_941870_200906',
#  'metrics_export_port': 63735,
#  'node_id': '59755b054a467786a78f67a77516f56099ec5486'}

# %%
import os
os.environ["TUNE_DISABLE_STRICT_METRIC_CHECKING"] = "1"

# %% [markdown]
# ### Evaluate uni-variate ts forecasting

# %%
df = pd.read_csv("data/retail_sales.csv")
df.index = pd.to_datetime(df["date"], format='%Y/%m/%d')
df.sort_index(inplace=True)

# %%
from gluonts.model.r_forecast import RForecastPredictor

# %%
train_data = ListDataset(
    [
        {
            "start": df["numer_retail_sales"].index[0],
            "target": df["numer_retail_sales"].values
        }
    ],
    freq="M")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a43b5aba23d9> in <module>
# ----> 1 train_data = ListDataset(
#       2     [
#       3         {
#       4             "start": df["numer_retail_sales"].index[0],
#       5             "target": df["numer_retail_sales"].values
#
# NameError: name 'ListDataset' is not defined

# %%
prediction_length = 100
m = actableai.timeseries.models.AAITimeseriesForecaster(
    prediction_length, mx.cpu(), torch.device("cpu"),
    actableai.timeseries.params.DeepARParams(
        num_cells=(1, 20), num_layers=(1, 3), epochs=(10, 50),
        context_length=(prediction_length, prediction_length*3)),
    feed_forward_params=actableai.timeseries.params.FeedForwardParams(),
    prophet_params=actableai.timeseries.params.ProphetParams(),
    rforecast_params=actableai.timeseries.params.RForecastParams())

# %%
m.fit(df[["numer_retail_sales",]], trials=10, max_concurrent=2)
# Out:
# 2021-01-29 13:24:57,446	WARNING function_runner.py:539 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# == Status ==<br>Memory usage on this node: 7.3/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_13-24-57<br>Number of trials: 1/10 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status  </th><th>loc  </th><th style="text-align: right;">  model/context_length</th><th style="text-align: right;">  model/epochs</th><th style="text-align: right;">  model/hidden_layer_size</th><th style="text-align: right;">  model/l2</th><th style="text-align: right;">  model/learning_rate</th><th>model/name  </th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_b5380cda</td><td>RUNNING </td><td>     </td><td style="text-align: right;">                    41</td><td style="text-align: right;">            63</td><td style="text-align: right;">                       15</td><td style="text-align: right;"> 0.0038515</td><td style="text-align: right;">           0.00355562</td><td>FeedForward </td></tr>
# </tbody>
# </table><br><br>
# (pid=190412) learning rate from ``lr_scheduler`` has been overwritten by ``learning_rate`` in optimizer.
#   0%|          | 0/50 [00:00<?, ?it/s]
# Result for trainable_b5380cda:
#   date: 2021-01-29_13-25-01
#   done: false
#   experiment_id: 88d12ecda5eb4d38a97e7054c007b504
#   hostname: minh-Precision-3520
#   iterations_since_restore: 1
#   node_ip: 172.16.2.58
#   pid: 190412
#   time_since_restore: 0.7145485877990723
#   time_this_iter_s: 0.7145485877990723
#   time_total_s: 0.7145485877990723
#   timestamp: 1611901501
#   timesteps_since_restore: 0
#   train_loss: 12.713693161010742
#   training_iteration: 1
#   trial_id: b5380cda
#
# 100%|██████████| 50/50 [00:00<00:00, 70.89it/s, epoch=1/63, avg_epoch_loss=12.7]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 79.37it/s, epoch=2/63, avg_epoch_loss=12]
#   0%|          | 0/50 [00:00<?, ?it/s]
# == Status ==<br>Memory usage on this node: 7.4/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_13-24-57<br>Number of trials: 2/10 (1 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status  </th><th>loc               </th><th style="text-align: right;">  model/context_length</th><th style="text-align: right;">  model/epochs</th><th style="text-align: right;">  model/hidden_layer_size</th><th style="text-align: right;">  model/l2</th><th style="text-align: right;">  model/learning_rate</th><th>model/name  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_b5380cda</td><td>RUNNING </td><td>172.16.2.58:190412</td><td style="text-align: right;">                    41</td><td style="text-align: right;">            63</td><td style="text-align: right;">                       15</td><td style="text-align: right;">0.0038515 </td><td style="text-align: right;">           0.00355562</td><td>FeedForward </td><td style="text-align: right;">     3</td><td style="text-align: right;">         1.97684</td><td style="text-align: right;">     11.8608</td></tr>
# <tr><td>trainable_b5380cdb</td><td>PENDING </td><td>                  </td><td style="text-align: right;">                    40</td><td style="text-align: right;">            57</td><td style="text-align: right;">                       38</td><td style="text-align: right;">0.00949672</td><td style="text-align: right;">           0.00155075</td><td>FeedForward </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td></tr>
# </tbody>
# </table><br><br>
# 100%|██████████| 50/50 [00:00<00:00, 80.82it/s, epoch=3/63, avg_epoch_loss=11.9]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 78.76it/s, epoch=4/63, avg_epoch_loss=11.8]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 81.41it/s, epoch=5/63, avg_epoch_loss=11.8]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 80.71it/s, epoch=6/63, avg_epoch_loss=11.7]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 80.57it/s, epoch=7/63, avg_epoch_loss=11.7]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 82.24it/s, epoch=8/63, avg_epoch_loss=11.7]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Result for trainable_b5380cda:
#   date: 2021-01-29_13-25-06
#   done: false
#   experiment_id: 88d12ecda5eb4d38a97e7054c007b504
#   hostname: minh-Precision-3520
#   iterations_since_restore: 9
#   node_ip: 172.16.2.58
#   pid: 190412
#   time_since_restore: 5.730047702789307
#   time_this_iter_s: 0.6299967765808105
#   time_total_s: 5.730047702789307
#   timestamp: 1611901506
#   timesteps_since_restore: 0
#   train_loss: 11.677293071746826
#   training_iteration: 9
#   trial_id: b5380cda
#
# 100%|██████████| 50/50 [00:00<00:00, 80.04it/s, epoch=9/63, avg_epoch_loss=11.7]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 78.22it/s, epoch=10/63, avg_epoch_loss=11.7]
#   0%|          | 0/50 [00:00<?, ?it/s]
# == Status ==<br>Memory usage on this node: 7.4/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_13-24-57<br>Number of trials: 2/10 (1 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status  </th><th>loc               </th><th style="text-align: right;">  model/context_length</th><th style="text-align: right;">  model/epochs</th><th style="text-align: right;">  model/hidden_layer_size</th><th style="text-align: right;">  model/l2</th><th style="text-align: right;">  model/learning_rate</th><th>model/name  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_b5380cda</td><td>RUNNING </td><td>172.16.2.58:190412</td><td style="text-align: right;">                    41</td><td style="text-align: right;">            63</td><td style="text-align: right;">                       15</td><td style="text-align: right;">0.0038515 </td><td style="text-align: right;">           0.00355562</td><td>FeedForward </td><td style="text-align: right;">    11</td><td style="text-align: right;">         7.10172</td><td style="text-align: right;">     11.6934</td></tr>
# <tr><td>trainable_b5380cdb</td><td>PENDING </td><td>                  </td><td style="text-align: right;">                    40</td><td style="text-align: right;">            57</td><td style="text-align: right;">                       38</td><td style="text-align: right;">0.00949672</td><td style="text-align: right;">           0.00155075</td><td>FeedForward </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td></tr>
# </tbody>
# </table><br><br>
# 100%|██████████| 50/50 [00:00<00:00, 69.22it/s, epoch=11/63, avg_epoch_loss=11.7]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 74.08it/s, epoch=12/63, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 78.21it/s, epoch=13/63, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 80.07it/s, epoch=14/63, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 82.76it/s, epoch=15/63, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 80.36it/s, epoch=16/63, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Result for trainable_b5380cda:
#   date: 2021-01-29_13-25-11
#   done: false
#   experiment_id: 88d12ecda5eb4d38a97e7054c007b504
#   hostname: minh-Precision-3520
#   iterations_since_restore: 17
#   node_ip: 172.16.2.58
#   pid: 190412
#   time_since_restore: 10.929370641708374
#   time_this_iter_s: 0.6362855434417725
#   time_total_s: 10.929370641708374
#   timestamp: 1611901511
#   timesteps_since_restore: 0
#   train_loss: 11.606064510345458
#   training_iteration: 17
#   trial_id: b5380cda
#
# 100%|██████████| 50/50 [00:00<00:00, 79.04it/s, epoch=17/63, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 77.31it/s, epoch=18/63, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# == Status ==<br>Memory usage on this node: 7.4/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_13-24-57<br>Number of trials: 2/10 (1 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status  </th><th>loc               </th><th style="text-align: right;">  model/context_length</th><th style="text-align: right;">  model/epochs</th><th style="text-align: right;">  model/hidden_layer_size</th><th style="text-align: right;">  model/l2</th><th style="text-align: right;">  model/learning_rate</th><th>model/name  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_b5380cda</td><td>RUNNING </td><td>172.16.2.58:190412</td><td style="text-align: right;">                    41</td><td style="text-align: right;">            63</td><td style="text-align: right;">                       15</td><td style="text-align: right;">0.0038515 </td><td style="text-align: right;">           0.00355562</td><td>FeedForward </td><td style="text-align: right;">    19</td><td style="text-align: right;">         12.2122</td><td style="text-align: right;">     11.6027</td></tr>
# <tr><td>trainable_b5380cdb</td><td>PENDING </td><td>                  </td><td style="text-align: right;">                    40</td><td style="text-align: right;">            57</td><td style="text-align: right;">                       38</td><td style="text-align: right;">0.00949672</td><td style="text-align: right;">           0.00155075</td><td>FeedForward </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td></tr>
# </tbody>
# </table><br><br>
# 100%|██████████| 50/50 [00:00<00:00, 79.78it/s, epoch=19/63, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 80.68it/s, epoch=20/63, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 77.30it/s, epoch=21/63, avg_epoch_loss=11.5]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 78.18it/s, epoch=22/63, avg_epoch_loss=11.5]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 79.03it/s, epoch=23/63, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 73.94it/s, epoch=24/63, avg_epoch_loss=11.5]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Result for trainable_b5380cda:
#   date: 2021-01-29_13-25-16
#   done: false
#   experiment_id: 88d12ecda5eb4d38a97e7054c007b504
#   hostname: minh-Precision-3520
#   iterations_since_restore: 25
#   node_ip: 172.16.2.58
#   pid: 190412
#   time_since_restore: 16.097225666046143
#   time_this_iter_s: 0.6460099220275879
#   time_total_s: 16.097225666046143
#   timestamp: 1611901516
#   timesteps_since_restore: 0
#   train_loss: 11.53964879989624
#   training_iteration: 25
#   trial_id: b5380cda
#
# 100%|██████████| 50/50 [00:00<00:00, 77.81it/s, epoch=25/63, avg_epoch_loss=11.5]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 79.30it/s, epoch=26/63, avg_epoch_loss=11.5]
#   0%|          | 0/50 [00:00<?, ?it/s]
# == Status ==<br>Memory usage on this node: 7.4/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_13-24-57<br>Number of trials: 2/10 (1 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status  </th><th>loc               </th><th style="text-align: right;">  model/context_length</th><th style="text-align: right;">  model/epochs</th><th style="text-align: right;">  model/hidden_layer_size</th><th style="text-align: right;">  model/l2</th><th style="text-align: right;">  model/learning_rate</th><th>model/name  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_b5380cda</td><td>RUNNING </td><td>172.16.2.58:190412</td><td style="text-align: right;">                    41</td><td style="text-align: right;">            63</td><td style="text-align: right;">                       15</td><td style="text-align: right;">0.0038515 </td><td style="text-align: right;">           0.00355562</td><td>FeedForward </td><td style="text-align: right;">    27</td><td style="text-align: right;">          17.362</td><td style="text-align: right;">      11.528</td></tr>
# <tr><td>trainable_b5380cdb</td><td>PENDING </td><td>                  </td><td style="text-align: right;">                    40</td><td style="text-align: right;">            57</td><td style="text-align: right;">                       38</td><td style="text-align: right;">0.00949672</td><td style="text-align: right;">           0.00155075</td><td>FeedForward </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td></tr>
# </tbody>
# </table><br><br>
# 100%|██████████| 50/50 [00:00<00:00, 80.09it/s, epoch=27/63, avg_epoch_loss=11.5]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 80.74it/s, epoch=28/63, avg_epoch_loss=11.5]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 79.55it/s, epoch=29/63, avg_epoch_loss=11.5]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 81.35it/s, epoch=30/63, avg_epoch_loss=11.5]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 78.88it/s, epoch=31/63, avg_epoch_loss=11.5]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 66.20it/s, epoch=32/63, avg_epoch_loss=11.5]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Result for trainable_b5380cda:
#   date: 2021-01-29_13-25-22
#   done: false
#   experiment_id: 88d12ecda5eb4d38a97e7054c007b504
#   hostname: minh-Precision-3520
#   iterations_since_restore: 33
#   node_ip: 172.16.2.58
#   pid: 190412
#   time_since_restore: 21.259361743927002
#   time_this_iter_s: 0.6237766742706299
#   time_total_s: 21.259361743927002
#   timestamp: 1611901522
#   timesteps_since_restore: 0
#   train_loss: 11.440166511535644
#   training_iteration: 33
#   trial_id: b5380cda
#
# 100%|██████████| 50/50 [00:00<00:00, 80.82it/s, epoch=33/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 80.14it/s, epoch=34/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# == Status ==<br>Memory usage on this node: 7.4/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_13-24-57<br>Number of trials: 2/10 (1 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status  </th><th>loc               </th><th style="text-align: right;">  model/context_length</th><th style="text-align: right;">  model/epochs</th><th style="text-align: right;">  model/hidden_layer_size</th><th style="text-align: right;">  model/l2</th><th style="text-align: right;">  model/learning_rate</th><th>model/name  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_b5380cda</td><td>RUNNING </td><td>172.16.2.58:190412</td><td style="text-align: right;">                    41</td><td style="text-align: right;">            63</td><td style="text-align: right;">                       15</td><td style="text-align: right;">0.0038515 </td><td style="text-align: right;">           0.00355562</td><td>FeedForward </td><td style="text-align: right;">    35</td><td style="text-align: right;">         22.5344</td><td style="text-align: right;">     11.4506</td></tr>
# <tr><td>trainable_b5380cdb</td><td>PENDING </td><td>                  </td><td style="text-align: right;">                    40</td><td style="text-align: right;">            57</td><td style="text-align: right;">                       38</td><td style="text-align: right;">0.00949672</td><td style="text-align: right;">           0.00155075</td><td>FeedForward </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td></tr>
# </tbody>
# </table><br><br>
# 100%|██████████| 50/50 [00:00<00:00, 78.49it/s, epoch=35/63, avg_epoch_loss=11.5]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 81.08it/s, epoch=36/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 80.48it/s, epoch=37/63, avg_epoch_loss=11.5]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 79.92it/s, epoch=38/63, avg_epoch_loss=11.5]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 80.52it/s, epoch=39/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 77.62it/s, epoch=40/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Result for trainable_b5380cda:
#   date: 2021-01-29_13-25-27
#   done: false
#   experiment_id: 88d12ecda5eb4d38a97e7054c007b504
#   hostname: minh-Precision-3520
#   iterations_since_restore: 41
#   node_ip: 172.16.2.58
#   pid: 190412
#   time_since_restore: 26.338507413864136
#   time_this_iter_s: 0.6542558670043945
#   time_total_s: 26.338507413864136
#   timestamp: 1611901527
#   timesteps_since_restore: 0
#   train_loss: 11.480079021453857
#   training_iteration: 41
#   trial_id: b5380cda
#
# 100%|██████████| 50/50 [00:00<00:00, 76.87it/s, epoch=41/63, avg_epoch_loss=11.5]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 78.01it/s, epoch=42/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# == Status ==<br>Memory usage on this node: 7.4/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_13-24-57<br>Number of trials: 2/10 (1 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status  </th><th>loc               </th><th style="text-align: right;">  model/context_length</th><th style="text-align: right;">  model/epochs</th><th style="text-align: right;">  model/hidden_layer_size</th><th style="text-align: right;">  model/l2</th><th style="text-align: right;">  model/learning_rate</th><th>model/name  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_b5380cda</td><td>RUNNING </td><td>172.16.2.58:190412</td><td style="text-align: right;">                    41</td><td style="text-align: right;">            63</td><td style="text-align: right;">                       15</td><td style="text-align: right;">0.0038515 </td><td style="text-align: right;">           0.00355562</td><td>FeedForward </td><td style="text-align: right;">    43</td><td style="text-align: right;">         27.6708</td><td style="text-align: right;">     11.4357</td></tr>
# <tr><td>trainable_b5380cdb</td><td>PENDING </td><td>                  </td><td style="text-align: right;">                    40</td><td style="text-align: right;">            57</td><td style="text-align: right;">                       38</td><td style="text-align: right;">0.00949672</td><td style="text-align: right;">           0.00155075</td><td>FeedForward </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td></tr>
# </tbody>
# </table><br><br>
# 100%|██████████| 50/50 [00:00<00:00, 73.28it/s, epoch=43/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 68.14it/s, epoch=44/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 79.79it/s, epoch=45/63, avg_epoch_loss=11.5]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 76.37it/s, epoch=46/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 79.32it/s, epoch=47/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 80.17it/s, epoch=48/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Result for trainable_b5380cda:
#   date: 2021-01-29_13-25-32
#   done: false
#   experiment_id: 88d12ecda5eb4d38a97e7054c007b504
#   hostname: minh-Precision-3520
#   iterations_since_restore: 49
#   node_ip: 172.16.2.58
#   pid: 190412
#   time_since_restore: 31.67240595817566
#   time_this_iter_s: 0.7067513465881348
#   time_total_s: 31.67240595817566
#   timestamp: 1611901532
#   timesteps_since_restore: 0
#   train_loss: 11.393823070526123
#   training_iteration: 49
#   trial_id: b5380cda
#
# 100%|██████████| 50/50 [00:00<00:00, 71.18it/s, epoch=49/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 81.89it/s, epoch=50/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# == Status ==<br>Memory usage on this node: 7.4/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_13-24-57<br>Number of trials: 2/10 (1 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status  </th><th>loc               </th><th style="text-align: right;">  model/context_length</th><th style="text-align: right;">  model/epochs</th><th style="text-align: right;">  model/hidden_layer_size</th><th style="text-align: right;">  model/l2</th><th style="text-align: right;">  model/learning_rate</th><th>model/name  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_b5380cda</td><td>RUNNING </td><td>172.16.2.58:190412</td><td style="text-align: right;">                    41</td><td style="text-align: right;">            63</td><td style="text-align: right;">                       15</td><td style="text-align: right;">0.0038515 </td><td style="text-align: right;">           0.00355562</td><td>FeedForward </td><td style="text-align: right;">    51</td><td style="text-align: right;">         32.9146</td><td style="text-align: right;">     11.3904</td></tr>
# <tr><td>trainable_b5380cdb</td><td>PENDING </td><td>                  </td><td style="text-align: right;">                    40</td><td style="text-align: right;">            57</td><td style="text-align: right;">                       38</td><td style="text-align: right;">0.00949672</td><td style="text-align: right;">           0.00155075</td><td>FeedForward </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td></tr>
# </tbody>
# </table><br><br>
# 100%|██████████| 50/50 [00:00<00:00, 80.41it/s, epoch=51/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 80.68it/s, epoch=52/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 82.58it/s, epoch=53/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 80.60it/s, epoch=54/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 82.42it/s, epoch=55/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 78.01it/s, epoch=56/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 80.46it/s, epoch=57/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Result for trainable_b5380cda:
#   date: 2021-01-29_13-25-38
#   done: false
#   experiment_id: 88d12ecda5eb4d38a97e7054c007b504
#   hostname: minh-Precision-3520
#   iterations_since_restore: 58
#   node_ip: 172.16.2.58
#   pid: 190412
#   time_since_restore: 37.26940298080444
#   time_this_iter_s: 0.6101155281066895
#   time_total_s: 37.26940298080444
#   timestamp: 1611901538
#   timesteps_since_restore: 0
#   train_loss: 11.398689060211181
#   training_iteration: 58
#   trial_id: b5380cda
#
# 100%|██████████| 50/50 [00:00<00:00, 82.46it/s, epoch=58/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 79.98it/s, epoch=59/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# == Status ==<br>Memory usage on this node: 7.4/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_13-24-57<br>Number of trials: 2/10 (1 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status  </th><th>loc               </th><th style="text-align: right;">  model/context_length</th><th style="text-align: right;">  model/epochs</th><th style="text-align: right;">  model/hidden_layer_size</th><th style="text-align: right;">  model/l2</th><th style="text-align: right;">  model/learning_rate</th><th>model/name  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_b5380cda</td><td>RUNNING </td><td>172.16.2.58:190412</td><td style="text-align: right;">                    41</td><td style="text-align: right;">            63</td><td style="text-align: right;">                       15</td><td style="text-align: right;">0.0038515 </td><td style="text-align: right;">           0.00355562</td><td>FeedForward </td><td style="text-align: right;">    60</td><td style="text-align: right;">         38.5123</td><td style="text-align: right;">     11.4158</td></tr>
# <tr><td>trainable_b5380cdb</td><td>PENDING </td><td>                  </td><td style="text-align: right;">                    40</td><td style="text-align: right;">            57</td><td style="text-align: right;">                       38</td><td style="text-align: right;">0.00949672</td><td style="text-align: right;">           0.00155075</td><td>FeedForward </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td></tr>
# </tbody>
# </table><br><br>
# 100%|██████████| 50/50 [00:00<00:00, 82.06it/s, epoch=60/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 82.70it/s, epoch=61/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 83.52it/s, epoch=62/63, avg_epoch_loss=11.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 77.85it/s, epoch=63/63, avg_epoch_loss=11.3]
# Running evaluation: 100%|██████████| 3/3 [00:00<00:00, 69.96it/s]
# Result for trainable_b5380cda:
#   date: 2021-01-29_13-25-41
#   done: true
#   experiment_id: 88d12ecda5eb4d38a97e7054c007b504
#   experiment_tag: 1_context_length=41,epochs=63,hidden_layer_size=15,l2=0.0038515,learning_rate=0.0035556,name=FeedForward
#   hostname: minh-Precision-3520
#   iterations_since_restore: 64
#   mean_wQuantileLoss: 0.16975865136819007
#   node_ip: 172.16.2.58
#   pid: 190412
#   time_since_restore: 40.430235147476196
#   time_this_iter_s: 0.05900454521179199
#   time_total_s: 40.430235147476196
#   timestamp: 1611901541
#   timesteps_since_restore: 0
#   training_iteration: 64
#   trial_id: b5380cda
#
# (pid=190408) learning rate from ``lr_scheduler`` has been overwritten by ``learning_rate`` in optimizer.
#   0%|          | 0/50 [00:00<?, ?it/s]
# Result for trainable_b5380cdb:
#   date: 2021-01-29_13-25-45
#   done: false
#   experiment_id: 0b0cce2973c84afca5abf297b60e9c20
#   hostname: minh-Precision-3520
#   iterations_since_restore: 1
#   node_ip: 172.16.2.58
#   pid: 190408
#   time_since_restore: 0.744905948638916
#   time_this_iter_s: 0.744905948638916
#   time_total_s: 0.744905948638916
#   timestamp: 1611901545
#   timesteps_since_restore: 0
#   train_loss: 12.693049850463867
#   training_iteration: 1
#   trial_id: b5380cdb
#
# 100%|██████████| 50/50 [00:00<00:00, 67.72it/s, epoch=1/57, avg_epoch_loss=12.7]
# == Status ==<br>Memory usage on this node: 7.4/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_13-24-57<br>Number of trials: 3/10 (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status    </th><th>loc               </th><th style="text-align: right;">  model/context_length</th><th style="text-align: right;">  model/epochs</th><th>model/growth  </th><th style="text-align: right;">  model/hidden_layer_size</th><th style="text-align: right;">  model/l2</th><th style="text-align: right;">  model/learning_rate</th><th>model/name  </th><th>model/seasonality_mode  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">  mean_wQuantileLoss</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_b5380cdb</td><td>RUNNING   </td><td>172.16.2.58:190408</td><td style="text-align: right;">                    40</td><td style="text-align: right;">            57</td><td>              </td><td style="text-align: right;">                       38</td><td style="text-align: right;">0.00949672</td><td style="text-align: right;">           0.00155075</td><td>FeedForward </td><td>                        </td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.744906</td><td style="text-align: right;">      12.693</td><td style="text-align: right;">                    </td></tr>
# <tr><td>trainable_cf4e19ac</td><td>PENDING   </td><td>                  </td><td style="text-align: right;">                      </td><td style="text-align: right;">              </td><td>linear        </td><td style="text-align: right;">                         </td><td style="text-align: right;">          </td><td style="text-align: right;">                     </td><td>Prophet     </td><td>multiplicative          </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td><td style="text-align: right;">                    </td></tr>
# <tr><td>trainable_b5380cda</td><td>TERMINATED</td><td>                  </td><td style="text-align: right;">                    41</td><td style="text-align: right;">            63</td><td>              </td><td style="text-align: right;">                       15</td><td style="text-align: right;">0.0038515 </td><td style="text-align: right;">           0.00355562</td><td>FeedForward </td><td>                        </td><td style="text-align: right;">    64</td><td style="text-align: right;">       40.4302  </td><td style="text-align: right;">            </td><td style="text-align: right;">            0.169759</td></tr>
# </tbody>
# </table><br><br>
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 77.61it/s, epoch=2/57, avg_epoch_loss=12]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 77.28it/s, epoch=3/57, avg_epoch_loss=11.9]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 78.04it/s, epoch=4/57, avg_epoch_loss=11.8]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 78.76it/s, epoch=5/57, avg_epoch_loss=11.8]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 78.46it/s, epoch=6/57, avg_epoch_loss=11.7]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 78.97it/s, epoch=7/57, avg_epoch_loss=11.7]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 78.80it/s, epoch=8/57, avg_epoch_loss=11.7]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Result for trainable_b5380cdb:
#   date: 2021-01-29_13-25-50
#   done: false
#   experiment_id: 0b0cce2973c84afca5abf297b60e9c20
#   hostname: minh-Precision-3520
#   iterations_since_restore: 9
#   node_ip: 172.16.2.58
#   pid: 190408
#   time_since_restore: 5.910048961639404
#   time_this_iter_s: 0.6478700637817383
#   time_total_s: 5.910048961639404
#   timestamp: 1611901550
#   timesteps_since_restore: 0
#   train_loss: 11.659136390686035
#   training_iteration: 9
#   trial_id: b5380cdb
# == Status ==<br>Memory usage on this node: 7.4/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_13-24-57<br>Number of trials: 3/10 (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status    </th><th>loc               </th><th style="text-align: right;">  model/context_length</th><th style="text-align: right;">  model/epochs</th><th>model/growth  </th><th style="text-align: right;">  model/hidden_layer_size</th><th style="text-align: right;">  model/l2</th><th style="text-align: right;">  model/learning_rate</th><th>model/name  </th><th>model/seasonality_mode  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">  mean_wQuantileLoss</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_b5380cdb</td><td>RUNNING   </td><td>172.16.2.58:190408</td><td style="text-align: right;">                    40</td><td style="text-align: right;">            57</td><td>              </td><td style="text-align: right;">                       38</td><td style="text-align: right;">0.00949672</td><td style="text-align: right;">           0.00155075</td><td>FeedForward </td><td>                        </td><td style="text-align: right;">     9</td><td style="text-align: right;">         5.91005</td><td style="text-align: right;">     11.6591</td><td style="text-align: right;">                    </td></tr>
# <tr><td>trainable_cf4e19ac</td><td>PENDING   </td><td>                  </td><td style="text-align: right;">                      </td><td style="text-align: right;">              </td><td>linear        </td><td style="text-align: right;">                         </td><td style="text-align: right;">          </td><td style="text-align: right;">                     </td><td>Prophet     </td><td>multiplicative          </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td><td style="text-align: right;">                    </td></tr>
# <tr><td>trainable_b5380cda</td><td>TERMINATED</td><td>                  </td><td style="text-align: right;">                    41</td><td style="text-align: right;">            63</td><td>              </td><td style="text-align: right;">                       15</td><td style="text-align: right;">0.0038515 </td><td style="text-align: right;">           0.00355562</td><td>FeedForward </td><td>                        </td><td style="text-align: right;">    64</td><td style="text-align: right;">        40.4302 </td><td style="text-align: right;">            </td><td style="text-align: right;">            0.169759</td></tr>
# </tbody>
# </table><br><br>
# 100%|██████████| 50/50 [00:00<00:00, 77.89it/s, epoch=9/57, avg_epoch_loss=11.7]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 77.20it/s, epoch=10/57, avg_epoch_loss=11.7]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 79.30it/s, epoch=11/57, avg_epoch_loss=11.7]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 78.33it/s, epoch=12/57, avg_epoch_loss=11.7]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 76.49it/s, epoch=13/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 77.84it/s, epoch=14/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 66.22it/s, epoch=15/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 78.85it/s, epoch=16/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Result for trainable_b5380cdb:
#   date: 2021-01-29_13-25-55
#   done: false
#   experiment_id: 0b0cce2973c84afca5abf297b60e9c20
#   hostname: minh-Precision-3520
#   iterations_since_restore: 17
#   node_ip: 172.16.2.58
#   pid: 190408
#   time_since_restore: 11.192238330841064
#   time_this_iter_s: 0.6465651988983154
#   time_total_s: 11.192238330841064
#   timestamp: 1611901555
#   timesteps_since_restore: 0
#   train_loss: 11.637606506347657
#   training_iteration: 17
#   trial_id: b5380cdb
# == Status ==<br>Memory usage on this node: 7.4/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_13-24-57<br>Number of trials: 3/10 (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status    </th><th>loc               </th><th style="text-align: right;">  model/context_length</th><th style="text-align: right;">  model/epochs</th><th>model/growth  </th><th style="text-align: right;">  model/hidden_layer_size</th><th style="text-align: right;">  model/l2</th><th style="text-align: right;">  model/learning_rate</th><th>model/name  </th><th>model/seasonality_mode  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">  mean_wQuantileLoss</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_b5380cdb</td><td>RUNNING   </td><td>172.16.2.58:190408</td><td style="text-align: right;">                    40</td><td style="text-align: right;">            57</td><td>              </td><td style="text-align: right;">                       38</td><td style="text-align: right;">0.00949672</td><td style="text-align: right;">           0.00155075</td><td>FeedForward </td><td>                        </td><td style="text-align: right;">    17</td><td style="text-align: right;">         11.1922</td><td style="text-align: right;">     11.6376</td><td style="text-align: right;">                    </td></tr>
# <tr><td>trainable_cf4e19ac</td><td>PENDING   </td><td>                  </td><td style="text-align: right;">                      </td><td style="text-align: right;">              </td><td>linear        </td><td style="text-align: right;">                         </td><td style="text-align: right;">          </td><td style="text-align: right;">                     </td><td>Prophet     </td><td>multiplicative          </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td><td style="text-align: right;">                    </td></tr>
# <tr><td>trainable_b5380cda</td><td>TERMINATED</td><td>                  </td><td style="text-align: right;">                    41</td><td style="text-align: right;">            63</td><td>              </td><td style="text-align: right;">                       15</td><td style="text-align: right;">0.0038515 </td><td style="text-align: right;">           0.00355562</td><td>FeedForward </td><td>                        </td><td style="text-align: right;">    64</td><td style="text-align: right;">         40.4302</td><td style="text-align: right;">            </td><td style="text-align: right;">            0.169759</td></tr>
# </tbody>
# </table><br><br>
# 100%|██████████| 50/50 [00:00<00:00, 77.99it/s, epoch=17/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 76.42it/s, epoch=18/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 77.91it/s, epoch=19/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 77.95it/s, epoch=20/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 76.07it/s, epoch=21/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 70.61it/s, epoch=22/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 72.35it/s, epoch=23/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 70.82it/s, epoch=24/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Result for trainable_b5380cdb:
#   date: 2021-01-29_13-26-01
#   done: false
#   experiment_id: 0b0cce2973c84afca5abf297b60e9c20
#   hostname: minh-Precision-3520
#   iterations_since_restore: 25
#   node_ip: 172.16.2.58
#   pid: 190408
#   time_since_restore: 16.561742544174194
#   time_this_iter_s: 0.6370630264282227
#   time_total_s: 16.561742544174194
#   timestamp: 1611901561
#   timesteps_since_restore: 0
#   train_loss: 11.592856388092041
#   training_iteration: 25
#   trial_id: b5380cdb
# == Status ==<br>Memory usage on this node: 7.4/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_13-24-57<br>Number of trials: 3/10 (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status    </th><th>loc               </th><th style="text-align: right;">  model/context_length</th><th style="text-align: right;">  model/epochs</th><th>model/growth  </th><th style="text-align: right;">  model/hidden_layer_size</th><th style="text-align: right;">  model/l2</th><th style="text-align: right;">  model/learning_rate</th><th>model/name  </th><th>model/seasonality_mode  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">  mean_wQuantileLoss</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_b5380cdb</td><td>RUNNING   </td><td>172.16.2.58:190408</td><td style="text-align: right;">                    40</td><td style="text-align: right;">            57</td><td>              </td><td style="text-align: right;">                       38</td><td style="text-align: right;">0.00949672</td><td style="text-align: right;">           0.00155075</td><td>FeedForward </td><td>                        </td><td style="text-align: right;">    25</td><td style="text-align: right;">         16.5617</td><td style="text-align: right;">     11.5929</td><td style="text-align: right;">                    </td></tr>
# <tr><td>trainable_cf4e19ac</td><td>PENDING   </td><td>                  </td><td style="text-align: right;">                      </td><td style="text-align: right;">              </td><td>linear        </td><td style="text-align: right;">                         </td><td style="text-align: right;">          </td><td style="text-align: right;">                     </td><td>Prophet     </td><td>multiplicative          </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td><td style="text-align: right;">                    </td></tr>
# <tr><td>trainable_b5380cda</td><td>TERMINATED</td><td>                  </td><td style="text-align: right;">                    41</td><td style="text-align: right;">            63</td><td>              </td><td style="text-align: right;">                       15</td><td style="text-align: right;">0.0038515 </td><td style="text-align: right;">           0.00355562</td><td>FeedForward </td><td>                        </td><td style="text-align: right;">    64</td><td style="text-align: right;">         40.4302</td><td style="text-align: right;">            </td><td style="text-align: right;">            0.169759</td></tr>
# </tbody>
# </table><br><br>
# 100%|██████████| 50/50 [00:00<00:00, 78.96it/s, epoch=25/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 76.23it/s, epoch=26/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 78.17it/s, epoch=27/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 75.07it/s, epoch=28/57, avg_epoch_loss=11.5]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 75.11it/s, epoch=29/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 71.87it/s, epoch=30/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 69.92it/s, epoch=31/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:00<00:00, 73.86it/s, epoch=32/57, avg_epoch_loss=11.6]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Result for trainable_b5380cdb:
#   date: 2021-01-29_13-26-06
#   done: false
#   experiment_id: 0b0cce2973c84afca5abf297b60e9c20
#   hostname: minh-Precision-3520
#   iterations_since_restore: 33
#   node_ip: 172.16.2.58
#   pid: 190408
#   time_since_restore: 21.959044218063354
#   time_this_iter_s: 0.6491007804870605
#   time_total_s: 21.959044218063354
#   timestamp: 1611901566
#   timesteps_since_restore: 0
#   train_loss: 11.584030952453613
#   training_iteration: 33
#   trial_id: b5380cdb
#
# 100%|██████████| 50/50 [00:00<00:00, 77.45it/s, epoch=33/57, avg_epoch_loss=11.6]
# == Status ==<br>Memory usage on this node: 7.4/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_13-24-57<br>Number of trials: 3/10 (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><table>
# <thead>
# ...
# <tr><td>trainable_eb106a0a</td><td>TERMINATED</td><td>                  </td><td style="text-align: right;">                    40</td><td style="text-align: right;">                    </td><td style="text-align: right;">            41</td><td>              </td><td style="text-align: right;">                       17</td><td style="text-align: right;">0.000302804</td><td style="text-align: right;">           0.00790704</td><td>                   </td><td>FeedForward </td><td style="text-align: right;">                 </td><td style="text-align: right;">                  </td><td>                        </td><td style="text-align: right;">    42</td><td style="text-align: right;">         26.2975</td><td style="text-align: right;">            </td><td style="text-align: right;">            0.152296</td></tr>
# <tr><td>trainable_cf4e19ac</td><td>ERROR     </td><td>                  </td><td style="text-align: right;">                      </td><td style="text-align: right;">                    </td><td style="text-align: right;">              </td><td>linear        </td><td style="text-align: right;">                         </td><td style="text-align: right;">           </td><td style="text-align: right;">                     </td><td>                   </td><td>Prophet     </td><td style="text-align: right;">                 </td><td style="text-align: right;">                  </td><td>multiplicative          </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td><td style="text-align: right;">                    </td></tr>
# <tr><td>trainable_12a409fa</td><td>ERROR     </td><td>                  </td><td style="text-align: right;">                      </td><td style="text-align: right;">                    </td><td style="text-align: right;">              </td><td>              </td><td style="text-align: right;">                         </td><td style="text-align: right;">           </td><td style="text-align: right;">                     </td><td>ets                </td><td>RForecast   </td><td style="text-align: right;">                 </td><td style="text-align: right;">                  </td><td>                        </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td><td style="text-align: right;">                    </td></tr>
# <tr><td>trainable_244edde2</td><td>ERROR     </td><td>                  </td><td style="text-align: right;">                      </td><td style="text-align: right;">                    </td><td style="text-align: rig
#   0%|          | 0/50 [00:00<?, ?it/s]
#  20%|██        | 10/50 [00:10<00:42,  1.05s/it, epoch=10/23, avg_epoch_loss=10.4]
#  40%|████      | 20/50 [00:20<00:31,  1.04s/it, epoch=10/23, avg_epoch_loss=10.4]
#  60%|██████    | 30/50 [00:31<00:20,  1.04s/it, epoch=10/23, avg_epoch_loss=10.4]
#  80%|████████  | 40/50 [00:41<00:10,  1.04s/it, epoch=10/23, avg_epoch_loss=10.4]
# Result for trainable_278b6660:
#   date: 2021-01-29_13-36-55
#   done: false
#   experiment_id: 5de41f8bea744b1f914b92a73b5dea95
#   hostname: minh-Precision-3520
#   iterations_since_restore: 10
#   node_ip: 172.16.2.58
#   pid: 190409
#   time_since_restore: 518.4619328975677
#   time_this_iter_s: 51.888423919677734
#   time_total_s: 518.4619328975677
#   timestamp: 1611902215
#   timesteps_since_restore: 0
#   train_loss: 10.43013111114502
#   training_iteration: 10
#   trial_id: 278b6660
#
# 100%|██████████| 50/50 [00:51<00:00,  1.04s/it, epoch=10/23, avg_epoch_loss=10.4]
# == Status ==<br>Memory usage on this node: 7.7/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_13-24-57<br>Number of trials: 9/10 (3 ERROR, 1 PENDING, 1 RUNNING, 4 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status    </th><th>loc               </th><th style="text-align: right;">  model/context_length</th><th style="text-align: right;">  model/dropout_rate</th><th style="text-align: right;">  model/epochs</th><th>model/growth  </th><th style="text-align: right;">  model/hidden_layer_size</th><th style="text-align: right;">   model/l2</th><th style="text-align: right;">  model/learning_rate</th><th>model/method_name  </th><th>model/name  </th><th style="text-align: right;">  model/num_cells</th><th style="text-align: right;">  model/num_layers</th><th>model/seasonality_mode  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">  mean_wQuantileLoss</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_278b6660</td><td>RUNNING   </td><td>172.16.2.58:190409</td><td style="text-align: right;">                   215</td><td style="text-align: right;">            0.293609</td><td style="text-align: right;">            23</td><td>              </td><td style="text-align: right;">                         </td><td style="text-align: right;">0.0081815  </td><td style="text-align: right;">           0.00638441</td><td>                   </td><td>DeepAR      </td><td style="text-align: right;">               15</td><td style="text-align: right;">                 2</td><td>                        </td><td style="text-align: right;">    10</td><td style="text-align: right;">        518.462 </td><td style="text-align: right;">     10.4301</td><td style="text-align: right;">                    </td></tr>
# <tr><td>trainable_2a4e34a4</td><td>PENDING   </td><td>                  </td><td style="text-align: right;">                    17</td><td style="text-align: right;">                    </td><td style="text-align: right;">            36</td><td>              </td><td style="text-align: right;">                       32</td><td style="text-align: right;">0.00590116 </td><td style="text-align: right;">           0.00334458</td><td>                   </td><td>FeedForward </td><td style="text-align: right;">                 </td><td style="text-align: right;">                  </td><td>                        </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td><td style="text-align: right;">                    </td></tr>
# <tr><td>trainable_b5380cda</td><td>TERMINATED</td><td>                  </td><td style="text-align: right;">                    41</td><td style="text-align: right;">                    </td><td style="text-align: right;">            63</td><td>              </td><td style="text-align: right;">                       15</td><td style="text-align: right;">0.0038515  </td><td style="text-align: right;">           0.00355562</td><td>                   </td><td>FeedForward </td><td style="text-align: right;">                 </td><td style="text-align: right;">                  </td><td>                        </td><td style="text-align: right;">    64</td><td style="text-align: right;">         40.4302</td><td style="text-align: right;">            </td><td style="text-align: right;">            0.169759</td></tr>
# <tr><td>trainable_b5380cdb</td><td>TERMINATED</td><td>                  </td><td style="text-align: right;">                    40</td><td style="text-align: right;">                    </td><td style="text-align: right;">            57</td><td>              </td><td style="text-align: right;">                       38</td><td style="text-align: right;">0.00949672 </td><td style="text-align: right;">           0.00155075</td><td>                   </td><td>FeedForward </td><td style="text-align: right;">                 </td><td style="text-align: right;">                  </td><td>                        </td><td style="text-align: right;">    58</td><td style="text-align: right;">         38.3679</td><td style="text-align: right;">            </td><td style="text-align: right;">            0.173485</td></tr>
# <tr><td>trainable_e83a346e</td><td>TERMINATED</td><td>                  </td><td style="text-align: right;">                    89</td><td style="text-align: right;">                    </td><td style="text-align: right;">            98</td><td>              </td><td style="text-align: right;">                        2</td><td style="text-align: right;">0.00699177 </td><td style="text-align: right;">           0.00536311</td><td>                   </td><td>FeedForward </td><td style="text-align: right;">                 </td><td style="text-align: right;">                  </td><td>                        </td><td style="text-align: right;">    99</td><td style="text-align: right;">         63.0556</td><td style="text-align: right;">            </td><td style="text-align: right;">            0.134105</td></tr>
# <tr><td>trainable_eb106a0a</td><td>TERMINATED</td><td>                  </td><td style="text-align: right;">                    40</td><td style="text-align: right;">                    </td><td style="text-align: right;">            41</td><td>              </td><td style="text-align: right;">                       17</td><td style="text-align: right;">0.000302804</td><td style="text-align: right;">           0.00790704</td><td>                   </td><td>FeedForward </td><td style="text-align: right;">                 </td><td style="text-align: right;">                  </td><td>                        </td><td style="text-align: right;">    42</td><td style="text-align: right;">         26.2975</td><td style="text-align: right;">            </td><td style="text-align: right;">            0.152296</td></tr>
# <tr><td>trainable_cf4e19ac</td><td>ERROR     </td><td>                  </td><td style="text-align: right;">                      </td><td style="text-align: right;">                    </td><td style="text-align: right;">              </td><td>linear        </td><td style="text-align: right;">                         </td><td style="text-align: right;">           </td><td style="text-align: right;">                     </td><td>                   </td><td>Prophet     </td><td style="text-align: right;">                 </td><td style="text-align: right;">                  </td><td>multiplicative          </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td><td style="text-align: right;">                    </td></tr>
# <tr><td>trainable_12a409fa</td><td>ERROR     </td><td>                  </td><td style="text-align: right;">                      </td><td style="text-align: right;">                    </td><td style="text-align: right;">              </td><td>              </td><td style="text-align: right;">                         </td><td style="text-align: right;">           </td><td style="text-align: right;">                     </td><td>ets                </td><td>RForecast   </td><td style="text-align: right;">                 </td><td style="text-align: right;">                  </td><td>                        </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td><td style="text-align: right;">                    </td></tr>
# <tr><td>trainable_244edde2</td><td>ERROR     </td><td>                  </td><td style="text-align: right;">                      </td><td style="text-align: right;">                    </td><td style="text-align: rig
#   0%|          | 0/50 [00:00<?, ?it/s]
#  18%|█▊        | 9/50 [00:10<00:47,  1.16s/it, epoch=11/23, avg_epoch_loss=10.5]
#  36%|███▌      | 18/50 [00:20<00:36,  1.15s/it, epoch=11/23, avg_epoch_loss=10.5]
#  54%|█████▍    | 27/50 [00:31<00:26,  1.16s/it, epoch=11/23, avg_epoch_loss=10.4]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-3cdfe7505761> in <module>
# ----> 1 m.fit(df[["numer_retail_sales",]], trials=10, max_concurrent=2)
#
# /usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/actableai/timeseries/models.py in fit(self, df, trials, loss, tune_params, max_concurrent, eval_samples)
#      97             else:
#      98                 distr_output = StudentTOutput()
# ---> 99             self.predictor = self._create_univariate_predictor(
#     100                 df[df.columns[0]], distr_output, trials, loss, tune_params, max_concurrent, eval_samples)
#     101         else:
#
# /usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/actableai/timeseries/models.py in _create_univariate_predictor(self, series, distr_output, trials, loss, tune_params, max_concurrent, eval_samples)
#     346         if tune_params is None:
#     347             tune_params = {}
# --> 348         analysis = tune.run(
#     349             trainable,
#     350             search_alg=algo,
#
# /usr/local/lib/python3.8/dist-packages/ray/tune/tune.py in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, local_dir, search_alg, scheduler, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, server_port, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial, callbacks, loggers, ray_auto_init, run_errored_only, global_checkpoint_period, with_server, upload_dir, sync_to_cloud, sync_to_driver, sync_on_checkpoint)
#     417     tune_start = time.time()
#     418     while not runner.is_finished():
# --> 419         runner.step()
#     420         if has_verbosity(Verbosity.V1_EXPERIMENT):
#     421             _report_progress(runner, progress_reporter)
#
# /usr/local/lib/python3.8/dist-packages/ray/tune/trial_runner.py in step(self)
#     358                     trial=next_trial)
#     359         elif self.trial_executor.get_running_trials():
# --> 360             self._process_events()  # blocking
#     361         else:
#     362             self.trial_executor.on_no_available_trials(self)
#
# /usr/local/lib/python3.8/dist-packages/ray/tune/trial_runner.py in _process_events(self)
#     467             # TODO(ujvl): Consider combining get_next_available_trial and
#     468             #  fetch_result functionality so that we don't timeout on fetch.
# --> 469             trial = self.trial_executor.get_next_available_trial()  # blocking
#     470             if trial.is_restoring:
#     471                 with warn_if_slow("process_trial_restore"):
#
# /usr/local/lib/python3.8/dist-packages/ray/tune/ray_trial_executor.py in get_next_available_trial(self)
#     470         # See https://github.com/ray-project/ray/issues/4211 for details.
#     471         start = time.time()
# --> 472         [result_id], _ = ray.wait(shuffled_results)
#     473         wait_time = time.time() - start
#     474         if wait_time > NONTRIVIAL_WAIT_TIME_THRESHOLD_S:
#
# /usr/local/lib/python3.8/dist-packages/ray/worker.py in wait(object_refs, num_returns, timeout)
#    1507         timeout = timeout if timeout is not None else 10**6
#    1508         timeout_milliseconds = int(timeout * 1000)
# -> 1509         ready_ids, remaining_ids = worker.core_worker.wait(
#    1510             object_refs,
#    1511             num_returns,
#
# python/ray/_raylet.pyx in ray._raylet.CoreWorker.wait()
#
# python/ray/_raylet.pyx in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %%
forecast = m.predict(df[["numer_retail_sales",]][:df.shape[0] - prediction_length])
fig, ax = plt.subplots(figsize=(12, 9))
ax.plot(df.index, df[["numer_retail_sales",]])
ax.plot(pd.to_datetime(forecast["date"]), forecast["values"][0][0]["q50"])
ax.fill_between(
    pd.to_datetime(forecast["date"]), 
    forecast["values"][0][0]["q5"], 
    forecast["values"][0][0]["q95"], 
    color='b', alpha=.1)

# %%
rs_1= m.score(df[["numer_retail_sales",]][:df.shape[0] - prediction_length])
pd.DataFrame.from_dict(rs_1['agg_metrics'],orient='index').rename(columns={0:'ActableAi'}).to_csv('retail_sales_notfull.csv')
pd.DataFrame.from_dict(rs_1['agg_metrics'],orient='index').rename(columns={0:'ActableAi'})

# %%
forecast = m.predict(df[["numer_retail_sales",]])
fig, ax = plt.subplots(figsize=(12, 9))
ax.plot(df.index, df[["numer_retail_sales",]])
ax.plot(pd.to_datetime(forecast["date"]), forecast["values"][0][0]["q50"])
ax.fill_between(
    pd.to_datetime(forecast["date"]), 
    forecast["values"][0][0]["q5"], 
    forecast["values"][0][0]["q95"], 
    color='b', alpha=.1)

# %%
rs_2= m.score(df[["numer_retail_sales",]][:df.shape[0] - prediction_length])
pd.DataFrame.from_dict(rs_2['agg_metrics'],orient='index').rename(columns={0:'ActableAi'}).to_csv('retail_sales_full.csv')
pd.DataFrame.from_dict(rs_2['agg_metrics'],orient='index').rename(columns={0:'ActableAi'})

# %% [markdown]
# ### Evaluate multi-variate ts forecasting

# %%
df = pd.read_csv("data/jane_empties.csv")

# %%
df.index = pd.to_datetime(df["order_date"], format='%m/%d/%Y')
df.sort_index(inplace=True)

# %%
prediction_length = 10
m = actableai.timeseries.models.AAITimeseriesForecaster(
    prediction_length, mx.cpu(), torch.device("cpu"),
    transformer_temp_flow_params=actableai.timeseries.params.TransformerTempFlowParams(epochs=1),
#     gp_var_params=actableai.timeseries.params.GPVarParams(epochs=1),
)

# %%
m.fit(df[["return_customers", "new_customers"]], trials=1)
# Out:
# == Status ==<br>Memory usage on this node: 8.9/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/4.49 GiB heap, 0.0/1.56 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-15_21-20-59<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status  </th><th>loc  </th><th style="text-align: right;">  model/context_length</th><th style="text-align: right;">  model/d_model</th><th style="text-align: right;">  model/epochs</th><th>model/flow_type  </th><th style="text-align: right;">  model/l2</th><th style="text-align: right;">  model/learning_rate</th><th>model/name         </th><th style="text-align: right;">  model/num_heads</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_e3cbb74a</td><td>RUNNING </td><td>     </td><td style="text-align: right;">                    86</td><td style="text-align: right;">              4</td><td style="text-align: right;">             1</td><td>MAF              </td><td style="text-align: right;"> 0.0075545</td><td style="text-align: right;">           0.00573803</td><td>TransformerTempFlow</td><td style="text-align: right;">                4</td></tr>
# </tbody>
# </table><br><br>
# 0it [00:00, ?it/s]
# 1it [00:00,  7.82it/s, avg_epoch_loss=2.02, epoch=0]
# 3it [00:00,  9.40it/s, avg_epoch_loss=2.07, epoch=0]
# 5it [00:00, 10.09it/s, avg_epoch_loss=2.03, epoch=0]
# 7it [00:00, 10.52it/s, avg_epoch_loss=1.95, epoch=0]
# 9it [00:00, 10.53it/s, avg_epoch_loss=1.99, epoch=0]
# 11it [00:01, 10.72it/s, avg_epoch_loss=1.99, epoch=0]
# 13it [00:01, 10.89it/s, avg_epoch_loss=1.97, epoch=0]
# 15it [00:01, 11.08it/s, avg_epoch_loss=1.98, epoch=0]
# 17it [00:01, 11.11it/s, avg_epoch_loss=1.98, epoch=0]
# 19it [00:01, 11.07it/s, avg_epoch_loss=1.97, epoch=0]
# 21it [00:01, 11.22it/s, avg_epoch_loss=1.96, epoch=0]
# 23it [00:02, 11.35it/s, avg_epoch_loss=1.97, epoch=0]
# 25it [00:02, 11.40it/s, avg_epoch_loss=1.95, epoch=0]
# 27it [00:02, 11.36it/s, avg_epoch_loss=1.94, epoch=0]
# 29it [00:02, 11.40it/s, avg_epoch_loss=1.93, epoch=0]
# 31it [00:02, 11.41it/s, avg_epoch_loss=1.92, epoch=0]
# 33it [00:02, 11.56it/s, avg_epoch_loss=1.91, epoch=0]
# 35it [00:03, 11.55it/s, avg_epoch_loss=1.9, epoch=0]
# 37it [00:03, 11.64it/s, avg_epoch_loss=1.89, epoch=0]
# 39it [00:03, 11.69it/s, avg_epoch_loss=1.89, epoch=0]
# 41it [00:03, 11.57it/s, avg_epoch_loss=1.88, epoch=0]
# 43it [00:03, 11.44it/s, avg_epoch_loss=1.87, epoch=0]
# 45it [00:04, 11.39it/s, avg_epoch_loss=1.86, epoch=0]
# 47it [00:04, 11.39it/s, avg_epoch_loss=1.85, epoch=0]
# 49it [00:04, 11.50it/s, avg_epoch_loss=1.85, epoch=0]
# 51it [00:04, 11.48it/s, avg_epoch_loss=1.84, epoch=0]
# 53it [00:04, 11.50it/s, avg_epoch_loss=1.83, epoch=0]
# 55it [00:04, 11.55it/s, avg_epoch_loss=1.82, epoch=0]
# 57it [00:05, 11.53it/s, avg_epoch_loss=1.81, epoch=0]
# 59it [00:05, 11.30it/s, avg_epoch_loss=1.8, epoch=0]
# 61it [00:05, 11.35it/s, avg_epoch_loss=1.8, epoch=0]
# 63it [00:05, 11.21it/s, avg_epoch_loss=1.79, epoch=0]
# 65it [00:05, 10.87it/s, avg_epoch_loss=1.79, epoch=0]
# 67it [00:06, 10.74it/s, avg_epoch_loss=1.78, epoch=0]
# 69it [00:06, 10.48it/s, avg_epoch_loss=1.77, epoch=0]
# 71it [00:06, 10.05it/s, avg_epoch_loss=1.77, epoch=0]
# 73it [00:06,  9.77it/s, avg_epoch_loss=1.76, epoch=0]
# 75it [00:06, 10.04it/s, avg_epoch_loss=1.76, epoch=0]
# 77it [00:07, 10.42it/s, avg_epoch_loss=1.76, epoch=0]
# 79it [00:07, 10.71it/s, avg_epoch_loss=1.75, epoch=0]
# 81it [00:07, 10.74it/s, avg_epoch_loss=1.75, epoch=0]
# 83it [00:07, 10.29it/s, avg_epoch_loss=1.75, epoch=0]
# 85it [00:07, 10.23it/s, avg_epoch_loss=1.75, epoch=0]
# 87it [00:07, 10.55it/s, avg_epoch_loss=1.74, epoch=0]
# 89it [00:08, 10.71it/s, avg_epoch_loss=1.74, epoch=0]
# 91it [00:08, 10.83it/s, avg_epoch_loss=1.74, epoch=0]
# 93it [00:08, 10.60it/s, avg_epoch_loss=1.74, epoch=0]
# 95it [00:08, 10.76it/s, avg_epoch_loss=1.74, epoch=0]
# 97it [00:08, 10.77it/s, avg_epoch_loss=1.73, epoch=0]
# 99it [00:09, 10.86it/s, avg_epoch_loss=1.73, epoch=0]
# 99it [00:09, 10.83it/s, avg_epoch_loss=1.73, epoch=0]
# (pid=37355) 2021-01-15 21:21:12,313	ERROR function_runner.py:254 -- Runner Thread raised error.
# (pid=37355) TypeError: only size-1 arrays can be converted to Python scalars
# (pid=37355)
# (pid=37355) The above exception was the direct cause of the following exception:
# (pid=37355)
# (pid=37355) Traceback (most recent call last):
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/ray/tune/function_runner.py", line 248, in run
# (pid=37355)     self._entrypoint()
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/ray/tune/function_runner.py", line 315, in entrypoint
# (pid=37355)     return self._trainable_func(self.config, self._status_reporter,
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/ray/tune/function_runner.py", line 575, in _trainable_func
# (pid=37355)     output = fn()
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/actableai/timeseries/models.py", line 219, in trainable
# (pid=37355)     forecasts = list(forecast_it)
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/model/predictor.py", line 124, in predict
# (pid=37355)     yield from self.forecast_generator(
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/model/forecast_generator.py", line 166, in __call__
# (pid=37355)     for batch in inference_data_loader:
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/dataset/loader.py", line 219, in __iter__
# (pid=37355)     for data_entry in self.transform(iter(self.dataset), is_train=False):
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/transform/transform.py", line 81, in __call__
# (pid=37355)     for data_entry in data_it:
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/transform/transform.py", line 128, in __call__
# (pid=37355)     for data_entry in data_it:
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/transform/transform.py", line 81, in __call__
# (pid=37355)     for data_entry in data_it:
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/transform/transform.py", line 81, in __call__
# (pid=37355)     for data_entry in data_it:
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/transform/transform.py", line 81, in __call__
# (pid=37355)     for data_entry in data_it:
# (pid=37355)   [Previous line repeated 5 more times]
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/gluonts/transform/dataset.py", line 44, in __iter__
# (pid=37355)     yield from self.transformations(self.base_dataset, is_train=True)
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/gluonts/transform/_base.py", line 92, in __call__
# (pid=37355)     for data_entry in data_it:
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/gluonts/dataset/common.py", line 283, in __iter__
# (pid=37355)     data = self.process(data)
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/gluonts/dataset/common.py", line 472, in __call__
# (pid=37355)     data = t(data)
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/gluonts/dataset/common.py", line 407, in __call__
# (pid=37355)     value = np.asarray(value, dtype=self.dtype)
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/numpy/core/_asarray.py", line 83, in asarray
# (pid=37355)     return array(a, dtype, copy=False, order=order)
# (pid=37355) ValueError: setting an array element with a sequence.
# (pid=37355) Exception in thread Thread-2:
# (pid=37355) TypeError: only size-1 arrays can be converted to Python scalars
# (pid=37355)
# (pid=37355) The above exception was the direct cause of the following exception:
# (pid=37355)
# (pid=37355) Traceback (most recent call last):
# (pid=37355)   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# (pid=37355)     self.run()
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/ray/tune/function_runner.py", line 267, in run
# (pid=37355)     raise e
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/ray/tune/function_runner.py", line 248, in run
# (pid=37355)     self._entrypoint()
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/ray/tune/function_runner.py", line 315, in entrypoint
# (pid=37355)     return self._trainable_func(self.config, self._status_reporter,
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/ray/tune/function_runner.py", line 575, in _trainable_func
# (pid=37355)     output = fn()
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/actableai/timeseries/models.py", line 219, in trainable
# (pid=37355)     forecasts = list(forecast_it)
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/model/predictor.py", line 124, in predict
# (pid=37355)     yield from self.forecast_generator(
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/model/forecast_generator.py", line 166, in __call__
# (pid=37355)     for batch in inference_data_loader:
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/dataset/loader.py", line 219, in __iter__
# (pid=37355)     for data_entry in self.transform(iter(self.dataset), is_train=False):
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/transform/transform.py", line 81, in __call__
# (pid=37355)     for data_entry in data_it:
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/transform/transform.py", line 128, in __call__
# (pid=37355)     for data_entry in data_it:
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/transform/transform.py", line 81, in __call__
# (pid=37355)     for data_entry in data_it:
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/transform/transform.py", line 81, in __call__
# (pid=37355)     for data_entry in data_it:
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/transform/transform.py", line 81, in __call__
# (pid=37355)     for data_entry in data_it:
# (pid=37355)   [Previous line repeated 5 more times]
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/gluonts/transform/dataset.py", line 44, in __iter__
# (pid=37355)     yield from self.transformations(self.base_dataset, is_train=True)
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/gluonts/transform/_base.py", line 92, in __call__
# (pid=37355)     for data_entry in data_it:
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/gluonts/dataset/common.py", line 283, in __iter__
# (pid=37355)     data = self.process(data)
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/gluonts/dataset/common.py", line 472, in __call__
# (pid=37355)     data = t(data)
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/gluonts/dataset/common.py", line 407, in __call__
# (pid=37355)     value = np.asarray(value, dtype=self.dtype)
# (pid=37355)   File "/usr/local/lib/python3.8/dist-packages/numpy/core/_asarray.py", line 83, in asarray
# (pid=37355)     return array(a, dtype, copy=False, order=order)
# (pid=37355) ValueError: setting an array element with a sequence.
# 2021-01-15 21:21:12,347	ERROR trial_runner.py:607 -- Trial trainable_e3cbb74a: Error processing event.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ray/tune/trial_runner.py", line 519, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/usr/local/lib/python3.8/dist-packages/ray/tune/ray_trial_executor.py", line 497, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/usr/local/lib/python3.8/dist-packages/ray/worker.py", line 1379, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train() (pid=37355, ip=172.16.2.58)
#   File "python/ray/_raylet.pyx", line 463, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 415, in ray._raylet.execute_task.function_executor
#   File "/usr/local/lib/python3.8/dist-packages/ray/tune/trainable.py", line 183, in train
#     result = self.step()
#   File "/usr/local/lib/python3.8/dist-packages/ray/tune/function_runner.py", line 366, in step
#     self._report_thread_runner_error(block=True)
#   File "/usr/local/lib/python3.8/dist-packages/ray/tune/function_runner.py", line 512, in _report_thread_runner_error
#     raise TuneError(("Trial raised an exception. Traceback:\n{}"
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ray::ImplicitFunc.train() (pid=37355, ip=172.16.2.58)
#   File "/usr/local/lib/python3.8/dist-packages/ray/tune/function_runner.py", line 248, in run
#     self._entrypoint()
#   File "/usr/local/lib/python3.8/dist-packages/ray/tune/function_runner.py", line 315, in entrypoint
#     return self._trainable_func(self.config, self._status_reporter,
#   File "/usr/local/lib/python3.8/dist-packages/ray/tune/function_runner.py", line 575, in _trainable_func
#     output = fn()
#   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/actableai/timeseries/models.py", line 219, in trainable
#     forecasts = list(forecast_it)
#   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/model/predictor.py", line 124, in predict
#     yield from self.forecast_generator(
#   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/model/forecast_generator.py", line 166, in __call__
#     for batch in inference_data_loader:
#   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/dataset/loader.py", line 219, in __iter__
#     for data_entry in self.transform(iter(self.dataset), is_train=False):
#   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/transform/transform.py", line 81, in __call__
#     for data_entry in data_it:
#   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/transform/transform.py", line 128, in __call__
#     for data_entry in data_it:
#   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/transform/transform.py", line 81, in __call__
#     for data_entry in data_it:
#   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/transform/transform.py", line 81, in __call__
#     for data_entry in data_it:
#   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/pts/transform/transform.py", line 81, in __call__
#     for data_entry in data_it:
#   [Previous line repeated 5 more times]
#   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/gluonts/transform/dataset.py", line 44, in __iter__
#     yield from self.transformations(self.base_dataset, is_train=True)
#   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/gluonts/transform/_base.py", line 92, in __call__
#     for data_entry in data_it:
#   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/gluonts/dataset/common.py", line 283, in __iter__
#     data = self.process(data)
#   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/gluonts/dataset/common.py", line 472, in __call__
#     data = t(data)
#   File "/usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/gluonts/dataset/common.py", line 407, in __call__
#     value = np.asarray(value, dtype=self.dtype)
#   File "/usr/local/lib/python3.8/dist-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: setting an array element with a sequence.
# Result for trainable_e3cbb74a:
#   {}
# == Status ==<br>Memory usage on this node: 9.2/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/8 CPUs, 0/1 GPUs, 0.0/4.49 GiB heap, 0.0/1.56 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-15_21-20-59<br>Number of trials: 1/1 (1 ERROR)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status  </th><th>loc  </th><th style="text-align: right;">  model/context_length</th><th style="text-align: right;">  model/d_model</th><th style="text-align: right;">  model/epochs</th><th>model/flow_type  </th><th style="text-align: right;">  model/l2</th><th style="text-align: right;">  model/learning_rate</th><th>model/name         </th><th style="text-align: right;">  model/num_heads</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_e3cbb74a</td><td>ERROR   </td><td>     </td><td style="text-align: right;">                    86</td><td style="text-align: right;">              4</td><td style="text-align: right;">             1</td><td>MAF              </td><td style="text-align: right;"> 0.0075545</td><td style="text-align: right;">           0.00573803</td><td>TransformerTempFlow</td><td style="text-align: right;">                4</td></tr>
# </tbody>
# </table><br>Number of errored trials: 1<br><table>
# <thead>
# <tr><th>Trial name        </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                                                                           </th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_e3cbb74a</td><td style="text-align: right;">           1</td><td>/home/minh/ray_results/trainable_2021-01-15_21-20-59/trainable_e3cbb74a_1_context_length=86,d_model=4,epochs=1,flow_type=MAF,l2=0.0075545,learning_rate=0.005738,name=TransformerTempFl_2021-01-15_21-20-59/error.txt</td></tr>
# </tbody>
# </table><br>
# == Status ==<br>Memory usage on this node: 9.2/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/8 CPUs, 0/1 GPUs, 0.0/4.49 GiB heap, 0.0/1.56 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-15_21-20-59<br>Number of trials: 1/1 (1 ERROR)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status  </th><th>loc  </th><th style="text-align: right;">  model/context_length</th><th style="text-align: right;">  model/d_model</th><th style="text-align: right;">  model/epochs</th><th>model/flow_type  </th><th style="text-align: right;">  model/l2</th><th style="text-align: right;">  model/learning_rate</th><th>model/name         </th><th style="text-align: right;">  model/num_heads</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_e3cbb74a</td><td>ERROR   </td><td>     </td><td style="text-align: right;">                    86</td><td style="text-align: right;">              4</td><td style="text-align: right;">             1</td><td>MAF              </td><td style="text-align: right;"> 0.0075545</td><td style="text-align: right;">           0.00573803</td><td>TransformerTempFlow</td><td style="text-align: right;">                4</td></tr>
# </tbody>
# </table><br>Number of errored trials: 1<br><table>
# <thead>
# <tr><th>Trial name        </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                                                                           </th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_e3cbb74a</td><td style="text-align: right;">           1</td><td>/home/minh/ray_results/trainable_2021-01-15_21-20-59/trainable_e3cbb74a_1_context_length=86,d_model=4,epochs=1,flow_type=MAF,l2=0.0075545,learning_rate=0.005738,name=TransformerTempFl_2021-01-15_21-20-59/error.txt</td></tr>
# </tbody>
# </table><br>
# ---------------------------------------------------------------------------
# TuneError                                 Traceback (most recent call last)
# <ipython-input-22-cf7344f490b9> in <module>
# ----> 1 m.fit(df[["return_customers", "new_customers"]], trials=1)
#
# /usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/actableai/timeseries/models.py in fit(self, df, trials, loss, tune_params, max_concurrent, eval_samples)
#     100                 df[df.columns[0]], distr_output, trials, loss, tune_params, max_concurrent, eval_samples)
#     101         else:
# --> 102             self.predictor = self._create_multivariate_predictor(
#     103                 df, trials, loss, tune_params, max_concurrent, eval_samples)
#     104
#
# /usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/actableai/timeseries/models.py in _create_multivariate_predictor(self, df, trials, loss, tune_params, max_concurrent, eval_samples)
#     241             tune_params = {}
#     242
# --> 243         analysis = tune.run(
#     244             trainable,
#     245             search_alg=algo,
#
# /usr/local/lib/python3.8/dist-packages/ray/tune/tune.py in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, local_dir, search_alg, scheduler, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, server_port, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial, callbacks, loggers, ray_auto_init, run_errored_only, global_checkpoint_period, with_server, upload_dir, sync_to_cloud, sync_to_driver, sync_on_checkpoint)
#     440     if incomplete_trials:
#     441         if raise_on_failed_trial:
# --> 442             raise TuneError("Trials did not complete", incomplete_trials)
#     443         else:
#     444             logger.error("Trials did not complete: %s", incomplete_trials)
#
# TuneError: ('Trials did not complete', [trainable_e3cbb74a])

# %%
sc=m.score(df[["return_customers", "new_customers"]])
sc.keys()
# Out:
# ---------------------------------------------------------------------------
# UntrainedModelException                   Traceback (most recent call last)
# <ipython-input-21-90da629bed2e> in <module>
# ----> 1 sc=m.score(df[["return_customers", "new_customers"]])
#       2 sc.keys()
#
# /usr/local/lib/python3.8/dist-packages/actableai-0.0.0-py3.8.egg/actableai/timeseries/models.py in score(self, df, num_samples, quantiles, num_workers)
#     105     def score(self, df, num_samples=100, quantiles=[0.1, 0.5, 0.95], num_workers=0):
#     106         if self.predictor is None:
# --> 107             raise UntrainedModelException()
#     108
#     109         target_dim = len(df.columns)
#
# UntrainedModelException:

# %%
pd.DataFrame.from_dict(sc['agg_metrics'],orient='index').rename(columns={0:'ActableAi'})
pd.DataFrame.from_dict(sc['agg_metrics'],orient='index').rename(columns={0:'ActableAi'}).to_csv('result_jane_empties.csv')

# %%
m.predict(df[["return_customers", "new_customers"]])

# %% [markdown]
# ### M4

# %%
# Load data
m4_info = pd.read_csv("data/M4-info.csv")
m4_info.index = m4_info['M4id']
m4_daily_train = pd.read_csv("data/Daily-train-m4.csv")
m4_daily_train.index = m4_daily_train['V1']
m4_hourly_train = pd.read_csv("data/Hourly-train-m4.csv")
m4_hourly_train.index = m4_hourly_train['V1']

# %%
m4_data = {'Info':m4_info,
           'Daily':m4_daily_train,
           'Hourly':m4_hourly_train}

# %%
num1_10 = np.arange(1, 11)
daily_series_name = ['D' + str(i) for i in num1_10]
hourly_series_name = ['H' + str(i) for i in num1_10]
daily_hourly_series_name = daily_series_name + hourly_series_name

# %%
def run_forecast(prediction_length, prediction_column_name, df, results):
    m = actableai.timeseries.models.AAITimeseriesForecaster(
        prediction_length, mx.cpu(), torch.device("cpu"),
        actableai.timeseries.params.DeepARParams(
            num_cells=(1, 20), num_layers=(1, 3), epochs=(10, 50),
            context_length=(prediction_length, prediction_length*3)),
        feed_forward_params=actableai.timeseries.params.FeedForwardParams(),
        prophet_params=actableai.timeseries.params.ProphetParams(),
        rforecast_params=actableai.timeseries.params.RForecastParams())
    
    m.fit(df[[prediction_column_name,]][:-prediction_length])

    predictions = m.predict(df[[prediction_column_name,]])
    print(predictions)

    score=m.score(df[[prediction_column_name,]][:-prediction_length])
    score['item_metrics']=score['item_metrics'].to_json()

    with open('actableai_metrics.json', 'w') as json_file:
        metrics[prediction_column_name] = score
        json.dump(metrics, json_file)

    with open('actableai_results.json', 'w') as json_file:
        results[prediction_column_name] = predictions["values"][0][0]['q50'].tolist()
        json.dump(results, json_file)

# %%
# Run forecasting algorithm
results = {}
metrics = {}
for series_name in daily_hourly_series_name:
    series_data = m4_data['Info'].loc[series_name,['StartingDate', 'Horizon', 'SP']]
    prediction_column_data = m4_data[series_data['SP']].loc[series_name].dropna().iloc[1:].values
    series_df = pd.DataFrame(prediction_column_data, columns=[series_name])

    if series_data['SP'] == 'Hourly':
        series_df.index = [pd.to_datetime(series_data['StartingDate'], format='%m/%d/%Y %H:%M') + timedelta(hours=i) for i in range(len(prediction_column_data))]
    elif series_data['SP'] == 'Daily':
        series_df.index = [pd.to_datetime(series_data['StartingDate'    ], format='%m/%d/%Y %H:%M') + timedelta(days=i) for i in range(len(prediction_column_data))]
        
    series_df = series_df.astype({series_name: float})
    run_forecast(series_data['Horizon'], series_name, series_df, results)
# Out:
# == Status ==<br>Memory usage on this node: 8.3/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_14-25-15<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status  </th><th>loc  </th><th>model/growth  </th><th>model/name  </th><th>model/seasonality_mode  </th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_218d3bb4</td><td>RUNNING </td><td>     </td><td>linear        </td><td>Prophet     </td><td>additive                </td></tr>
# </tbody>
# </table><br><br>
# Running evaluation:   0%|          | 0/3 [00:00<?, ?it/s]
# (pid=194389) INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# (pid=194389) Initial log joint probability = -3.34066
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)       99       4192.71     0.0185727       2470.03           1           1      123
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      199       4260.44   0.000361854       432.114           1           1      243
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      299       4273.23   2.74107e-05       611.041       0.395       0.395      360
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      399       4285.75     0.0103776       2216.38           1           1      476
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      499       4298.46    0.00123216       2409.47       0.308           1      590
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      599       4310.01   0.000450613       526.311      0.7161      0.7161      698
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      699       4315.72   0.000931845       179.526      0.8881      0.8881      817
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      799       4320.84   0.000133722       260.708      0.8854      0.8854      930
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      899       4322.38   0.000617366       516.589           1           1     1051
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      921       4322.82   1.39504e-05       123.986   1.037e-07       0.001     1120  LS failed, Hessian reset
# (pid=194389)      999        4323.3   5.42472e-05       235.995           1           1     1219
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1045       4323.38   5.98065e-06       217.667   1.468e-08       0.001     1318  LS failed, Hessian reset
# (pid=194389)     1061        4323.4   5.87603e-06       153.285   1.016e-07       0.001     1382  LS failed, Hessian reset
# (pid=194389)     1091       4323.42   8.73686e-06       185.552   1.023e-07       0.001     1456  LS failed, Hessian reset
# (pid=194389)     1099       4323.42   3.92479e-06       50.4615           1           1     1465
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1199       4324.16   0.000496689       173.678           1           1     1583
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1299       4325.42    0.00120296       269.909       1.205      0.1205     1701
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1325       4326.36    1.0093e-05       417.311    1.62e-08       0.001     1788  LS failed, Hessian reset
# (pid=194389)     1399       4326.85   0.000992413       282.108           1           1     1881
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1405       4326.86   2.37428e-06       105.923   2.334e-08       0.001     1936  LS failed, Hessian reset
# (pid=194389)     1421       4326.99   4.03643e-06       177.916   1.973e-08       0.001     1997  LS failed, Hessian reset
# (pid=194389)     1445       4327.06   8.49889e-06       315.925   1.445e-08       0.001     2070  LS failed, Hessian reset
# (pid=194389)     1499       4327.11   5.63796e-06       131.819      0.5709      0.5709     2131
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1512       4327.15    9.4478e-06       245.319   1.187e-08       0.001     2186  LS failed, Hessian reset
# (pid=194389)     1542       4327.19   7.11698e-06       148.497   8.166e-08       0.001     2264  LS failed, Hessian reset
# (pid=194389)     1577       4327.21   1.41819e-06        63.195   1.671e-08       0.001     2365  LS failed, Hessian reset
# (pid=194389)     1599       4327.21   6.15028e-05       130.682           1           1     2391
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1699       4327.33    0.00117931       101.805           1           1     2522
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1718       4327.38   6.87741e-06         243.2   1.358e-08       0.001     2589  LS failed, Hessian reset
# (pid=194389)     1799       4327.45   8.15636e-05       72.7204      0.2755           1     2693
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1826       4327.46   1.14102e-05       325.523    8.87e-08       0.001     2767  LS failed, Hessian reset
# (pid=194389)     1899        4327.5   3.16022e-05       70.6625           1           1     2862
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1919        4327.5   3.17356e-06       129.715   3.751e-08       0.001     2939  LS failed, Hessian reset
# (pid=194389)     1999       4327.52   1.79492e-05       108.037      0.9607      0.9607     3044
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     2039       4327.53   2.46575e-07       46.3006      0.2523      0.2523     3100
# (pid=194389) Optimization terminated normally:
# (pid=194389)   Convergence detected: relative gradient magnitude is below tolerance
# (pid=194389) INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# (pid=194389) Initial log joint probability = -3.92729
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)       99       4175.99   0.000654708       1223.86           1           1      123
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      199       4210.42    0.00210591       900.445           1           1      236
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      299       4219.57   0.000728665       427.083           1           1      350
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      399       4222.73   0.000208499       201.688           1           1      468
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      499       4224.26    0.00341546        226.28           1           1      585
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      599        4225.7   0.000755574       149.532           1           1      700
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      615       4225.81   6.52736e-06       196.547   6.497e-08       0.001      771  LS failed, Hessian reset
# (pid=194389)      658       4226.25    7.4397e-06        201.12   1.317e-08       0.001      872  LS failed, Hessian reset
# (pid=194389)      699       4226.64   0.000231054       87.5835           1           1      921
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      706       4226.65   3.34677e-06       119.034   1.562e-08       0.001      983  LS failed, Hessian reset
# (pid=194389)      733       4226.83   2.60953e-06         100.9   2.875e-08       0.001     1056  LS failed, Hessian reset
# (pid=194389)      799       4227.33    0.00123528       742.996       3.671      0.3671     1134
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      899       4230.43    0.00820191       648.859           1           1     1250
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      997       4231.26    8.4706e-06       292.449   1.422e-08       0.001     1408  LS failed, Hessian reset
# (pid=194389)      999       4231.27   3.73693e-05       220.066           1           1     1411
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1039       4231.48   2.96547e-06       69.1073   1.228e-08       0.001     1498  LS failed, Hessian reset
# (pid=194389)     1084       4231.62   1.04133e-05       337.838   4.076e-08       0.001     1597  LS failed, Hessian reset
# (pid=194389)     1099       4231.68   0.000528466       289.053           1           1     1612
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1146       4231.78   2.10511e-06       89.8931    2.46e-08       0.001     1711  LS failed, Hessian reset
# (pid=194389)     1199       4231.88   0.000138991       204.714       1.946      0.1946     1771
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1267       4232.16   1.75857e-06       66.8961   1.597e-08       0.001     1899  LS failed, Hessian reset
# (pid=194389)     1299       4232.18   5.37673e-05       105.832      0.7501      0.7501     1940
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1302       4232.18   1.49952e-06       66.4571   2.065e-08       0.001     1991  LS failed, Hessian reset
# (pid=194389)     1399       4232.57    0.00229981       290.183           1           1     2105
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1499       4232.99   0.000207795       217.403           1           1     2228
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1599       4233.17   3.05219e-05       76.6587      0.6684      0.6684     2366
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1699       4233.21   7.46366e-06       71.2524      0.3887        0.89     2491
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1711       4233.21   5.34424e-06       132.798   1.022e-07       0.001     2548  LS failed, Hessian reset
# (pid=194389)     1785       4233.29   7.15077e-06       270.662   1.818e-08       0.001     2680  LS failed, Hessian reset
# (pid=194389)     1799       4233.33   0.000112878       259.429      0.4759      0.4759     2697
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1899       4233.38    0.00017981       88.4334           1           1     2824
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)     1903       4233.39   3.75517e-06       147.932   2.395e-08       0.001     2884  LS failed, Hessian reset
# (pid=194389)     1925       4233.39   4.78027e-07       42.5289           1           1     2913
# (pid=194389) Optimization terminated normally:
# (pid=194389)   Convergence detected: relative gradient magnitude is below tolerance
# (pid=194389) INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# (pid=194389) INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# (pid=194389) Initial log joint probability = -2.04196
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)       99        614.68    0.00559835       921.103           1           1      120
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      199        621.11   0.000802968       107.961       1.806      0.1806      236
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      299       622.791   0.000366549       73.3742           1           1      367
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      399       623.504    0.00371206       132.776      0.3966           1      504
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      492       624.721    1.7276e-05       157.369   1.611e-07       0.001      676  LS failed, Hessian reset
# (pid=194389)      499       624.803   9.16543e-05       299.487      0.6546      0.6546      683
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      533       625.062   1.29542e-05       133.463   6.647e-08       0.001      773  LS failed, Hessian reset
# (pid=194389)      599       625.319     0.0025118       331.985      0.4602           1      861
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      604       625.339   4.21288e-05       217.559   4.808e-07       0.001      912  LS failed, Hessian reset
# (pid=194389)      653       625.494   4.14657e-05       263.653   3.707e-07       0.001     1010  LS failed, Hessian reset
# (pid=194389)      699       625.561   0.000180968       138.518           1           1     1065
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      799       625.704   2.08059e-06       78.4304      0.2965      0.2965     1206
# (pid=194389)     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# (pid=194389)      826       625.704   1.48869e-08       66.1543      0.2113      0.2113     1246
# (pid=194389) Optimization terminated normally:
# (pid=194389)   Convergence detected: relative gradient magnitude is below tolerance
# Result for trainable_218d3bb4:
#   date: 2021-01-29_14-25-22
#   done: false
#   experiment_id: cc8c4259355041dca2189ee9bf2c317f
#   hostname: minh-Precision-3520
#   iterations_since_restore: 1
#   mean_wQuantileLoss: 0.010534507580631373
#   node_ip: 172.16.2.58
#   pid: 194389
#   time_since_restore: 3.717945098876953
#   time_this_iter_s: 3.717945098876953
#   time_total_s: 3.717945098876953
#   timestamp: 1611905122
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 218d3bb4
# == Status ==<br>Memory usage on this node: 8.5/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_14-25-15<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status  </th><th>loc               </th><th>model/growth  </th><th>model/name  </th><th>model/seasonality_mode  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  mean_wQuantileLoss</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_218d3bb4</td><td>RUNNING </td><td>172.16.2.58:194389</td><td>linear        </td><td>Prophet     </td><td>additive                </td><td style="text-align: right;">     1</td><td style="text-align: right;">         3.71795</td><td style="text-align: right;">           0.0105345</td></tr>
# </tbody>
# </table><br><br>
# Result for trainable_218d3bb4:
#   date: 2021-01-29_14-25-22
#   done: true
#   experiment_id: cc8c4259355041dca2189ee9bf2c317f
#   experiment_tag: 1_growth=linear,name=Prophet,seasonality_mode=additive
#   hostname: minh-Precision-3520
#   iterations_since_restore: 1
#   mean_wQuantileLoss: 0.010534507580631373
#   node_ip: 172.16.2.58
#   pid: 194389
#   time_since_restore: 3.717945098876953
#   time_this_iter_s: 3.717945098876953
#   time_total_s: 3.717945098876953
#   timestamp: 1611905122
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 218d3bb4
# == Status ==<br>Memory usage on this node: 8.5/15.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/8 CPUs, 0/1 GPUs, 0.0/5.22 GiB heap, 0.0/1.81 GiB objects (0/1.0 accelerator_type:M620)<br>Result logdir: /home/minh/ray_results/trainable_2021-01-29_14-25-15<br>Number of trials: 1/1 (1 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name        </th><th>status    </th><th>loc  </th><th>model/growth  </th><th>model/name  </th><th>model/seasonality_mode  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  mean_wQuantileLoss</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_218d3bb4</td><td>TERMINATED</td><td>     </td><td>linear        </td><td>Prophet     </td><td>additive                </td><td style="text-align: right;">     1</td><td style="text-align: right;">         3.71795</td><td style="text-align: right;">           0.0105345</td></tr>
# </tbody>
# </table><br><br>
# 2021-01-29 14:25:22,512	INFO tune.py:448 -- Total run time: 7.29 seconds (7.28 seconds for the tuning loop).
# Running evaluation: 100%|██████████| 3/3 [00:03<00:00,  1.24s/it]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# {'date': ['1996-12-01 12:00:00', '1996-12-02 12:00:00', '1996-12-03 12:00:00', '1996-12-04 12:00:00', '1996-12-05 12:00:00', '1996-12-06 12:00:00', '1996-12-07 12:00:00', '1996-12-08 12:00:00', '1996-12-09 12:00:00', '1996-12-10 12:00:00', '1996-12-11 12:00:00', '1996-12-12 12:00:00', '1996-12-13 12:00:00', '1996-12-14 12:00:00'], 'values': [[{'q5': array([1975.30039704, 1980.22463638, 1979.43931043, 1976.22626197,
#        1976.6754248 , 1970.30642207, 1971.91255956, 1968.7890031 ,
#        1969.26447479, 1969.6695835 , 1968.77018859, 1972.34189787,
#        1963.89150558, 1969.06736068]), 'q50': array([1999.18332099, 1995.80264535, 1997.07165527, 1994.7720916 ,
#        1994.52006643, 1993.25713961, 1995.36359097, 1991.17967654,
#        1991.68103347, 1991.91198588, 1989.37297525, 1988.36280271,
#        1988.48490149, 1991.77567947]), 'q95': array([2020.24298148, 2016.22474487, 2016.85273367, 2015.74065394,
#        2012.29743482, 2014.27278259, 2016.94011102, 2010.36076986,
#        2009.17210146, 2008.20204186, 2009.85495102, 2009.30648634,
#        2009.66740237, 2010.53691749])}]]}
# Running evaluation: 100%|██████████| 1/1 [00:00<00:00, 120.90it/s]

# %%
print("")

# %%
metrics=json.load(open('actableai_metrics.json',))

# %%
d={}
for u in metrics.keys():
    d[u]=metrics[u]['agg_metrics']
        
pd.DataFrame(d)
# Out:
#                                D1            D2            D3            D4  \
# MSE                    429.711147  11661.800223  26089.098214  77683.141506
# abs_error              247.741089   1239.496338   1752.432129   3095.089178
# abs_target_sum       27766.296875  42266.496094  15222.299805  14714.000000
# abs_target_mean       1983.306920   3019.035435   1087.307129   1051.000000
# seasonal_error           4.395702     14.522722      4.476240     38.285714
# MASE                     4.025704      6.096340     27.964034      5.774420
# MAPE                     0.008886      0.029087      0.107275      0.194189
# sMAPE                    0.008928      0.029726      0.117751      0.211895
# OWA                           NaN           NaN           NaN           NaN
# MSIS                    25.879129     26.120966   1010.622030     28.334506
# QuantileLoss[0.1]      104.946924    478.924902    367.921899   1114.618333
# Coverage[0.1]            0.000000      0.000000      0.000000      0.000000
# QuantileLoss[0.5]      247.741089   1239.496338   1752.432068   3095.089178
# Coverage[0.5]            0.428571      0.000000      0.000000      0.428571
# QuantileLoss[0.95]      41.114929    337.071582   3080.296759    573.968826
# Coverage[0.95]           1.000000      0.571429      0.357143      0.928571
# RMSE                    20.729475    107.989815    161.521201    278.716956
# NRMSE                    0.010452      0.035770      0.148552      0.265192
# ND                       0.008922      0.029326      0.115123      0.210350
# wQuantileLoss[0.1]       0.003780      0.011331      0.024170      0.075752
# wQuantileLoss[0.5]       0.008922      0.029326      0.115123      0.210350
# wQuantileLoss[0.95]      0.001481      0.007975      0.202354      0.039008
# mean_wQuantileLoss       0.004728      0.016211      0.113882      0.108370
# MAE_Coverage             0.073810      0.326190      0.397619      0.064286
#
#                                D5            D6             D7            D8  \
# MSE                   7789.095432  13540.429688  182463.982143   1862.712752
# abs_error             1142.533833   1441.065186    5152.441406    523.164174
# abs_target_sum       79038.835938  41674.609375   58760.359375  23351.310547
# abs_target_mean       5645.631138   2976.757812    4197.168527   1667.950753
# seasonal_error          52.578271     14.566638     253.227754      7.677227
# MASE                     1.552154      7.066368       1.453362      4.867495
# MAPE                     0.014420      0.035024       0.091205      0.022294
# sMAPE                    0.014549      0.034405       0.089676      0.022632
# OWA                           NaN           NaN            NaN           NaN
# MSIS                    34.966858     27.460587      14.364538     44.919940
# QuantileLoss[0.1]     1608.009316    669.954199    3417.206567    181.102828
# Coverage[0.1]            0.000000      0.428571       0.000000      0.000000
# QuantileLoss[0.5]     1142.533833   1441.065186    5152.441162    523.164174
# Coverage[0.5]            0.000000      0.714286       0.285714      0.000000
# QuantileLoss[0.95]     980.518470    306.006812    1751.039478    265.846168
# Coverage[0.95]           1.000000      1.000000       1.000000      0.571429
# RMSE                    88.255852    116.363352     427.158029     43.159156
# NRMSE                    0.015633      0.039091       0.101773      0.025876
# ND                       0.014455      0.034579       0.087686      0.022404
# wQuantileLoss[0.1]       0.020345      0.016076       0.058155      0.007756
# wQuantileLoss[0.5]       0.014455      0.034579       0.087686      0.022404
# wQuantileLoss[0.95]      0.012406      0.007343       0.029800      0.011385
# mean_wQuantileLoss       0.015735      0.019333       0.058547      0.013848
# MAE_Coverage             0.216667      0.197619       0.121429      0.326190
#
#                                D9           D10            H1             H2  \
# MSE                   1945.355305  19286.030061   4220.318034   66583.413097
# abs_error              547.231554   1925.494085   2603.527344   11233.586712
# abs_target_sum       21418.242188  35211.101562  31017.000000  139752.000000
# abs_target_mean       1529.874442   2515.078683    646.187500    2911.500000
# seasonal_error           7.311475     19.644490     43.612069     171.912069
# MASE                     5.346112      7.001215      1.243696       1.361353
# MAPE                     0.025448      0.054579      0.092090       0.089052
# sMAPE                    0.025859      0.056172      0.088807       0.083692
# OWA                           NaN           NaN           NaN            NaN
# MSIS                    51.637666     44.460786      8.939841      11.455720
# QuantileLoss[0.1]      183.128885    601.833702   1305.845111    7735.641283
# Coverage[0.1]            0.000000      0.000000      0.229167       0.687500
# QuantileLoss[0.5]      547.231554   1925.494085   2603.527313   11233.586712
# Coverage[0.5]            0.000000      0.000000      0.604167       0.958333
# QuantileLoss[0.95]     281.823624    774.360388    677.367194    2150.315156
# Coverage[0.95]           0.500000      0.214286      0.979167       1.000000
# RMSE                    44.106182    138.874152     64.963975     258.037620
# NRMSE                    0.028830      0.055217      0.100534       0.088627
# ND                       0.025550      0.054684      0.083939       0.080382
# wQuantileLoss[0.1]       0.008550      0.017092      0.042101       0.055353
# wQuantileLoss[0.5]       0.025550      0.054684      0.083939       0.080382
# wQuantileLoss[0.95]      0.013158      0.021992      0.021839       0.015387
# mean_wQuantileLoss       0.015753      0.031256      0.049293       0.050374
# MAE_Coverage             0.350000      0.445238      0.087500       0.365278
#
#                                H3             H4             H5  \
# MSE                   7990.889323   72142.657306  129443.574477
# abs_error             3392.728027   11383.928706   14721.947006
# abs_target_sum       51051.000000  226208.000000  107417.000000
# abs_target_mean       1063.562500    4712.666667    2237.854167
# seasonal_error          79.375862     266.625862     195.872414
# MASE                     0.890470       0.889506       1.565852
# MAPE                     0.064130       0.056141       0.130145
# sMAPE                    0.067271       0.053946       0.140474
# OWA                           NaN            NaN            NaN
# MSIS                    11.658480       5.376775      18.278805
# QuantileLoss[0.1]     1073.793481    5678.832063    4778.074199
# Coverage[0.1]            0.020833       0.583333       0.000000
# QuantileLoss[0.5]     3392.728027   11383.928706   14721.947006
# Coverage[0.5]            0.166667       0.916667       0.000000
# QuantileLoss[0.95]    2507.606317    2459.052905    9246.041350
# Coverage[0.95]           0.458333       1.000000       0.416667
# RMSE                    89.391774     268.593852     359.782677
# NRMSE                    0.084049       0.056994       0.160771
# ND                       0.066458       0.050325       0.137054
# wQuantileLoss[0.1]       0.021034       0.025104       0.044482
# wQuantileLoss[0.5]       0.066458       0.050325       0.137054
# wQuantileLoss[0.95]      0.049120       0.010871       0.086076
# mean_wQuantileLoss       0.045537       0.028767       0.089204
# MAE_Coverage             0.301389       0.316667       0.377778
#
#                                 H6            H7            H8            H9  \
# MSE                  229452.354820  4.544558e+07  2.940053e+06  6.112975e+06
# abs_error             20332.386108  2.618774e+05  6.102782e+04  9.926794e+04
# abs_target_sum       288449.000000  1.707506e+06  1.407481e+06  1.709547e+06
# abs_target_mean        6009.354167  3.557304e+04  2.932252e+04  3.561556e+04
# seasonal_error          202.270690  1.877052e+03  1.629333e+03  1.890016e+03
# MASE                      2.094181  2.906568e+00  7.803274e-01  1.094214e+00
# MAPE                      0.071581  1.625942e-01  3.925941e-02  5.571341e-02
# sMAPE                     0.074987  1.481898e-01  4.047589e-02  5.357783e-02
# OWA                            NaN           NaN           NaN           NaN
# MSIS                     32.729900  2.258746e+01  6.874025e+00  9.618637e+00
# QuantileLoss[0.1]      6138.744830  1.067579e+05  2.025017e+04  7.560958e+04
# Coverage[0.1]             0.000000  1.250000e-01  2.083333e-02  6.250000e-01
# QuantileLoss[0.5]     20332.386108  2.618774e+05  6.102782e+04  9.926794e+04
# Coverage[0.5]             0.041667  7.291667e-01  2.291667e-01  9.375000e-01
# QuantileLoss[0.95]    17759.019787  7.846231e+04  3.707621e+04  1.858540e+04
# Coverage[0.95]            0.333333  1.000000e+00  5.625000e-01  1.000000e+00
# RMSE                    479.011852  6.741334e+03  1.714658e+03  2.472443e+03
# NRMSE                     0.079711  1.895068e-01  5.847582e-02  6.942030e-02
# ND                        0.070489  1.533683e-01  4.335961e-02  5.806681e-02
# wQuantileLoss[0.1]        0.021282  6.252270e-02  1.438753e-02  4.422784e-02
# wQuantileLoss[0.5]        0.070489  1.533683e-01  4.335961e-02  5.806681e-02
# wQuantileLoss[0.95]       0.061567  4.595141e-02  2.634225e-02  1.087153e-02
# mean_wQuantileLoss        0.051113  8.728082e-02  2.802979e-02  3.772206e-02
# MAE_Coverage              0.391667  1.013889e-01  2.458333e-01  3.375000e-01
#
#                               H10
# MSE                   1129.065131
# abs_error             1280.941833
# abs_target_sum       19723.000000
# abs_target_mean        410.895833
# seasonal_error          10.037931
# MASE                     2.658545
# MAPE                     0.064643
# sMAPE                    0.067896
# OWA                           NaN
# MSIS                    18.131468
# QuantileLoss[0.1]      506.366963
# Coverage[0.1]            0.000000
# QuantileLoss[0.5]     1280.941833
# Coverage[0.5]            0.041667
# QuantileLoss[0.95]     435.036048
# Coverage[0.95]           0.708333
# RMSE                    33.601564
# NRMSE                    0.081776
# ND                       0.064947
# wQuantileLoss[0.1]       0.025674
# wQuantileLoss[0.5]       0.064947
# wQuantileLoss[0.95]      0.022057
# mean_wQuantileLoss       0.037559
# MAE_Coverage             0.266667
